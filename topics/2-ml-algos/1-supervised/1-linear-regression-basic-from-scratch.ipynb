# %% [markdown]
# # Linear Regression
# most basic algo.
#
# Two Types:
# 1. Simple Linear Regression (SLR)
# 2. Multiple Linear Regression (MLR)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Simple Linear Regression
# In simple linear regression, we model the relationship between two variables by fitting a straight line to the data. The `equation of the line` is given by:
#
# $${ y = \beta_0 + \beta_1 x }$$
#
# - ${ y }$ is the dependent variable (target).
# - ${ x }$ is the independent variable (predictor).
# - ${ \beta_0 }$ is the y-intercept (the value of ${ y }$ when ${ x = 0 }$).
# - ${ \beta_1 }$ is the slope of the line (the change in ${ y }$ for a one-unit change in ${ x }$).

# %%
# example dataset, scores after each hour
hours = [1, 2, 3, 4, 5]
scores = [1.5, 3.2, 4.8, 8.5, 11.5]

# %% [markdown]
# ### Simplest Algorithm

# %%
# independant and dependant variables
x = np.array(hours)
y = np.array(scores)

# %%
# Initialize parameters

b0 = 0  # Intercept
b1 = 0  # Slope

learning_rate = 0.01
iterations = 1000

# %%
print("Before: b0 =", b0, "and b1 =", b1)
# Out:
# Before: b0 = 0 and b1 = 0

# %%
# Train

# Calculate the prediction
for _ in range(iterations): # epochs
    m = len(y)

    for i in range(m):
        predicted = b0 + b1 * x[i]

        # Calculate the error
        error = predicted - y[i]

        # Update the weights
        b0 -= learning_rate * error
        b1 -= learning_rate * error * hours[i]

# %%
print("After: b0 =", b0, "and b1 =", b1)
# Out:
# After: b0 = -1.773159591514913 and b1 = 2.573774778247447

# %%
# predict
print(f"input={x[1]},\npredicted={b0 + b1 * x[1]}\nactual = {y[1]}\nerror = {(b0 + b1 * x[1]) - y[1]}\nerror %age = {round(abs(((b0 + b1 * x[1]) - y[1]) / y[1]) * 100 ,2)}% ")
# Out:
# input=2,
# predicted=3.374389964979981
# actual = 3.2
# error = 0.17438996497998094
# error %age = 5.45%

# %%
def mse(X, y, b0, b1): # mean squared error (cost function)
  c = len(y)

  total_error = 0
  for i in range(c):
    total_error += (
      # result
      b0 +
      b1 * X[i]

      # minus actual
      - y[i]
    ) ** 2 # raise to two
  return total_error / (2 * c)

# %% [markdown]
# ## 2. Multiple Linear Regression
# In multiple linear regression, we model the relationship between one dependent variable and `multiple independent variables`. The equation is given by:
#
# $${ y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \ldots + \beta_n x_n }$$
#
# - ${ y }$ is the dependent variable.
# - ${ x_1, x_2, \ldots, x_n }$ are the independent variables.
# - ${ \beta_0, \beta_1, \beta_2, \ldots, \beta_n }$ are the coefficients.

# %%
# sample dataset

hours_studied         = np.array([1,   2,   3,   4,   5   ])
assignments_completed = np.array([1,   1,   2,   2,   3   ])
scores                = np.array([1.5, 3.2, 4.8, 8.5, 11.5])

# %%
# input and output
X = np.column_stack([hours_studied, assignments_completed])
Y = scores

# %%
weights = np.full(X.shape[1:], 1.0)
bias = 0.0

learning_rate = 0.01
iterations = 1000

# %%
c = len(Y)
for _ in range(iterations): # epochs
  for i in range(c):
    predicted = np.dot(X[i], weights)
    error = predicted - Y[i]
    weights -= learning_rate * error * X[i]
  print("iteration =", _, " weights = ", weights)
# Out:
# iteration = 0  weights =  [ 2.75627415 -1.05738389]
# iteration = 1  weights =  [ 2.75648528 -1.0577451 ]
# iteration = 2  weights =  [ 2.75669577 -1.05810522]
# iteration = 3  weights =  [ 2.75690564 -1.05846427]
# iteration = 4  weights =  [ 2.75711488 -1.05882225]
# iteration = 5  weights =  [ 2.75732349 -1.05917916]
# iteration = 6  weights =  [ 2.75753149 -1.059535  ]
# iteration = 7  weights =  [ 2.75773885 -1.05988977]
# iteration = 8  weights =  [ 2.7579456  -1.06024348]
# iteration = 9  weights =  [ 2.75815173 -1.06059614]
# iteration = 10  weights =  [ 2.75835725 -1.06094774]
# iteration = 11  weights =  [ 2.75856215 -1.0612983 ]
# iteration = 12  weights =  [ 2.75876644 -1.0616478 ]
# iteration = 13  weights =  [ 2.75897011 -1.06199626]
# iteration = 14  weights =  [ 2.75917318 -1.06234367]
# iteration = 15  weights =  [ 2.75937564 -1.06269005]
# iteration = 16  weights =  [ 2.7595775  -1.06303539]
# iteration = 17  weights =  [ 2.75977875 -1.0633797 ]
# iteration = 18  weights =  [ 2.7599794  -1.06372298]
# iteration = 19  weights =  [ 2.76017945 -1.06406524]
# iteration = 20  weights =  [ 2.7603789  -1.06440647]
# iteration = 21  weights =  [ 2.76057776 -1.06474668]
# iteration = 22  weights =  [ 2.76077602 -1.06508587]
# iteration = 23  weights =  [ 2.76097369 -1.06542405]
# iteration = 24  weights =  [ 2.76117076 -1.06576122]
# iteration = 25  weights =  [ 2.76136725 -1.06609738]
# iteration = 26  weights =  [ 2.76156315 -1.06643253]
# iteration = 27  weights =  [ 2.76175847 -1.06676668]
# iteration = 28  weights =  [ 2.7619532  -1.06709984]
# iteration = 29  weights =  [ 2.76214735 -1.06743199]
# iteration = 30  weights =  [ 2.76234092 -1.06776316]
# iteration = 31  weights =  [ 2.7625339  -1.06809333]
# iteration = 32  weights =  [ 2.76272632 -1.06842252]
# iteration = 33  weights =  [ 2.76291815 -1.06875072]
# iteration = 34  weights =  [ 2.76310942 -1.06907795]
# iteration = 35  weights =  [ 2.76330011 -1.06940419]
# iteration = 36  weights =  [ 2.76349023 -1.06972946]
# iteration = 37  weights =  [ 2.76367979 -1.07005375]
# iteration = 38  weights =  [ 2.76386877 -1.07037708]
# iteration = 39  weights =  [ 2.76405719 -1.07069944]
# iteration = 40  weights =  [ 2.76424505 -1.07102083]
# iteration = 41  weights =  [ 2.76443235 -1.07134127]
# iteration = 42  weights =  [ 2.76461909 -1.07166074]
# iteration = 43  weights =  [ 2.76480526 -1.07197926]
# iteration = 44  weights =  [ 2.76499089 -1.07229683]
# iteration = 45  weights =  [ 2.76517595 -1.07261345]
# iteration = 46  weights =  [ 2.76536047 -1.07292913]
# iteration = 47  weights =  [ 2.76554443 -1.07324385]
# iteration = 48  weights =  [ 2.76572784 -1.07355764]
# iteration = 49  weights =  [ 2.7659107  -1.07387049]
# iteration = 50  weights =  [ 2.76609302 -1.07418241]
# iteration = 51  weights =  [ 2.76627479 -1.07449339]
# iteration = 52  weights =  [ 2.76645602 -1.07480344]
# iteration = 53  weights =  [ 2.7666367  -1.07511257]
# iteration = 54  weights =  [ 2.76681685 -1.07542077]
# iteration = 55  weights =  [ 2.76699646 -1.07572805]
# iteration = 56  weights =  [ 2.76717553 -1.07603441]
# iteration = 57  weights =  [ 2.76735406 -1.07633985]
# iteration = 58  weights =  [ 2.76753206 -1.07664438]
# iteration = 59  weights =  [ 2.76770953 -1.076948  ]
# iteration = 60  weights =  [ 2.76788647 -1.07725072]
# iteration = 61  weights =  [ 2.76806288 -1.07755253]
# iteration = 62  weights =  [ 2.76823876 -1.07785343]
# iteration = 63  weights =  [ 2.76841412 -1.07815344]
# iteration = 64  weights =  [ 2.76858895 -1.07845255]
# iteration = 65  weights =  [ 2.76876326 -1.07875076]
# iteration = 66  weights =  [ 2.76893705 -1.07904809]
# iteration = 67  weights =  [ 2.76911032 -1.07934452]
# iteration = 68  weights =  [ 2.76928307 -1.07964007]
# iteration = 69  weights =  [ 2.7694553  -1.07993473]
# iteration = 70  weights =  [ 2.76962702 -1.08022852]
# iteration = 71  weights =  [ 2.76979823 -1.08052142]
# iteration = 72  weights =  [ 2.76996892 -1.08081345]
# iteration = 73  weights =  [ 2.7701391  -1.08110461]
# iteration = 74  weights =  [ 2.77030878 -1.08139489]
# iteration = 75  weights =  [ 2.77047794 -1.08168431]
# iteration = 76  weights =  [ 2.77064661 -1.08197286]
# iteration = 77  weights =  [ 2.77081476 -1.08226055]
# iteration = 78  weights =  [ 2.77098242 -1.08254738]
# iteration = 79  weights =  [ 2.77114957 -1.08283336]
# iteration = 80  weights =  [ 2.77131622 -1.08311847]
# iteration = 81  weights =  [ 2.77148238 -1.08340274]
# iteration = 82  weights =  [ 2.77164804 -1.08368615]
# iteration = 83  weights =  [ 2.7718132  -1.08396872]
# iteration = 84  weights =  [ 2.77197787 -1.08425044]
# iteration = 85  weights =  [ 2.77214205 -1.08453132]
# iteration = 86  weights =  [ 2.77230573 -1.08481136]
# iteration = 87  weights =  [ 2.77246893 -1.08509057]
# iteration = 88  weights =  [ 2.77263164 -1.08536893]
# iteration = 89  weights =  [ 2.77279386 -1.08564647]
# iteration = 90  weights =  [ 2.7729556  -1.08592318]
# iteration = 91  weights =  [ 2.77311685 -1.08619906]
# iteration = 92  weights =  [ 2.77327762 -1.08647411]
# iteration = 93  weights =  [ 2.77343791 -1.08674834]
# iteration = 94  weights =  [ 2.77359772 -1.08702175]
# iteration = 95  weights =  [ 2.77375706 -1.08729435]
# iteration = 96  weights =  [ 2.77391591 -1.08756613]
# iteration = 97  weights =  [ 2.7740743 -1.0878371]
# iteration = 98  weights =  [ 2.77423221 -1.08810725]
# iteration = 99  weights =  [ 2.77438964 -1.0883766 ]
# iteration = 100  weights =  [ 2.77454661 -1.08864515]
# iteration = 101  weights =  [ 2.77470311 -1.08891289]
# iteration = 102  weights =  [ 2.77485913 -1.08917983]
# iteration = 103  weights =  [ 2.7750147  -1.08944597]
# iteration = 104  weights =  [ 2.77516979 -1.08971132]
# iteration = 105  weights =  [ 2.77532443 -1.08997587]
# iteration = 106  weights =  [ 2.7754786  -1.09023963]
# iteration = 107  weights =  [ 2.77563231 -1.09050261]
# iteration = 108  weights =  [ 2.77578556 -1.09076479]
# iteration = 109  weights =  [ 2.77593835 -1.0910262 ]
# iteration = 110  weights =  [ 2.77609069 -1.09128682]
# iteration = 111  weights =  [ 2.77624257 -1.09154666]
# iteration = 112  weights =  [ 2.77639399 -1.09180573]
# iteration = 113  weights =  [ 2.77654497 -1.09206402]
# iteration = 114  weights =  [ 2.77669549 -1.09232154]
# iteration = 115  weights =  [ 2.77684556 -1.09257829]
# iteration = 116  weights =  [ 2.77699519 -1.09283427]
# iteration = 117  weights =  [ 2.77714436 -1.09308948]
# iteration = 118  weights =  [ 2.77729309 -1.09334394]
# iteration = 119  weights =  [ 2.77744138 -1.09359763]
# iteration = 120  weights =  [ 2.77758922 -1.09385056]
# iteration = 121  weights =  [ 2.77773662 -1.09410274]
# iteration = 122  weights =  [ 2.77788358 -1.09435416]
# iteration = 123  weights =  [ 2.7780301  -1.09460484]
# iteration = 124  weights =  [ 2.77817618 -1.09485476]
# iteration = 125  weights =  [ 2.77832182 -1.09510393]
# iteration = 126  weights =  [ 2.77846703 -1.09535237]
# iteration = 127  weights =  [ 2.77861181 -1.09560005]
# iteration = 128  weights =  [ 2.77875615 -1.095847  ]
# iteration = 129  weights =  [ 2.77890006 -1.09609321]
# iteration = 130  weights =  [ 2.77904354 -1.09633868]
# iteration = 131  weights =  [ 2.7791866  -1.09658342]
# iteration = 132  weights =  [ 2.77932922 -1.09682743]
# iteration = 133  weights =  [ 2.77947142 -1.0970707 ]
# iteration = 134  weights =  [ 2.77961319 -1.09731325]
# iteration = 135  weights =  [ 2.77975454 -1.09755508]
# iteration = 136  weights =  [ 2.77989546 -1.09779618]
# iteration = 137  weights =  [ 2.78003597 -1.09803656]
# iteration = 138  weights =  [ 2.78017605 -1.09827622]
# iteration = 139  weights =  [ 2.78031572 -1.09851517]
# iteration = 140  weights =  [ 2.78045497 -1.0987534 ]
# iteration = 141  weights =  [ 2.7805938  -1.09899092]
# iteration = 142  weights =  [ 2.78073222 -1.09922773]
# iteration = 143  weights =  [ 2.78087022 -1.09946383]
# iteration = 144  weights =  [ 2.78100781 -1.09969922]
# iteration = 145  weights =  [ 2.78114499 -1.09993392]
# iteration = 146  weights =  [ 2.78128176 -1.10016791]
# iteration = 147  weights =  [ 2.78141812 -1.1004012 ]
# iteration = 148  weights =  [ 2.78155407 -1.10063379]
# iteration = 149  weights =  [ 2.78168962 -1.10086568]
# iteration = 150  weights =  [ 2.78182476 -1.10109689]
# iteration = 151  weights =  [ 2.78195949 -1.1013274 ]
# iteration = 152  weights =  [ 2.78209383 -1.10155722]
# iteration = 153  weights =  [ 2.78222776 -1.10178636]
# iteration = 154  weights =  [ 2.78236129 -1.10201481]
# iteration = 155  weights =  [ 2.78249442 -1.10224258]
# iteration = 156  weights =  [ 2.78262716 -1.10246967]
# iteration = 157  weights =  [ 2.78275949 -1.10269607]
# iteration = 158  weights =  [ 2.78289143 -1.10292181]
# iteration = 159  weights =  [ 2.78302298 -1.10314686]
# iteration = 160  weights =  [ 2.78315414 -1.10337125]
# iteration = 161  weights =  [ 2.7832849  -1.10359496]
# iteration = 162  weights =  [ 2.78341527 -1.103818  ]
# iteration = 163  weights =  [ 2.78354525 -1.10404038]
# iteration = 164  weights =  [ 2.78367484 -1.10426209]
# iteration = 165  weights =  [ 2.78380405 -1.10448314]
# iteration = 166  weights =  [ 2.78393287 -1.10470353]
# iteration = 167  weights =  [ 2.7840613  -1.10492326]
# iteration = 168  weights =  [ 2.78418935 -1.10514233]
# iteration = 169  weights =  [ 2.78431702 -1.10536075]
# iteration = 170  weights =  [ 2.7844443  -1.10557851]
# iteration = 171  weights =  [ 2.78457121 -1.10579562]
# iteration = 172  weights =  [ 2.78469773 -1.10601209]
# iteration = 173  weights =  [ 2.78482388 -1.1062279 ]
# iteration = 174  weights =  [ 2.78494965 -1.10644308]
# iteration = 175  weights =  [ 2.78507504 -1.1066576 ]
# iteration = 176  weights =  [ 2.78520006 -1.10687149]
# iteration = 177  weights =  [ 2.7853247  -1.10708474]
# iteration = 178  weights =  [ 2.78544898 -1.10729735]
# iteration = 179  weights =  [ 2.78557288 -1.10750932]
# iteration = 180  weights =  [ 2.78569641 -1.10772066]
# iteration = 181  weights =  [ 2.78581957 -1.10793137]
# iteration = 182  weights =  [ 2.78594236 -1.10814145]
# iteration = 183  weights =  [ 2.78606479 -1.1083509 ]
# iteration = 184  weights =  [ 2.78618685 -1.10855973]
# iteration = 185  weights =  [ 2.78630854 -1.10876793]
# iteration = 186  weights =  [ 2.78642987 -1.1089755 ]
# iteration = 187  weights =  [ 2.78655084 -1.10918246]
# iteration = 188  weights =  [ 2.78667145 -1.1093888 ]
# iteration = 189  weights =  [ 2.78679169 -1.10959452]
# iteration = 190  weights =  [ 2.78691158 -1.10979962]
# iteration = 191  weights =  [ 2.7870311  -1.11000412]
# iteration = 192  weights =  [ 2.78715028 -1.110208  ]
# iteration = 193  weights =  [ 2.78726909 -1.11041127]
# iteration = 194  weights =  [ 2.78738755 -1.11061394]
# iteration = 195  weights =  [ 2.78750565 -1.11081599]
# iteration = 196  weights =  [ 2.7876234  -1.11101745]
# iteration = 197  weights =  [ 2.7877408 -1.1112183]
# iteration = 198  weights =  [ 2.78785785 -1.11141855]
# iteration = 199  weights =  [ 2.78797455 -1.1116182 ]
# iteration = 200  weights =  [ 2.7880909  -1.11181726]
# iteration = 201  weights =  [ 2.7882069  -1.11201572]
# iteration = 202  weights =  [ 2.78832256 -1.11221359]
# iteration = 203  weights =  [ 2.78843787 -1.11241086]
# iteration = 204  weights =  [ 2.78855283 -1.11260755]
# iteration = 205  weights =  [ 2.78866745 -1.11280364]
# iteration = 206  weights =  [ 2.78878173 -1.11299916]
# iteration = 207  weights =  [ 2.78889567 -1.11319408]
# iteration = 208  weights =  [ 2.78900926 -1.11338843]
# iteration = 209  weights =  [ 2.78912252 -1.11358219]
# iteration = 210  weights =  [ 2.78923543 -1.11377537]
# iteration = 211  weights =  [ 2.78934801 -1.11396798]
# iteration = 212  weights =  [ 2.78946026 -1.11416001]
# iteration = 213  weights =  [ 2.78957217 -1.11435147]
# iteration = 214  weights =  [ 2.78968374 -1.11454235]
# iteration = 215  weights =  [ 2.78979498 -1.11473266]
# iteration = 216  weights =  [ 2.78990589 -1.11492241]
# iteration = 217  weights =  [ 2.79001646 -1.11511158]
# iteration = 218  weights =  [ 2.79012671 -1.11530019]
# iteration = 219  weights =  [ 2.79023662 -1.11548824]
# iteration = 220  weights =  [ 2.79034621 -1.11567573]
# iteration = 221  weights =  [ 2.79045547 -1.11586265]
# iteration = 222  weights =  [ 2.7905644  -1.11604902]
# iteration = 223  weights =  [ 2.790673   -1.11623482]
# iteration = 224  weights =  [ 2.79078129 -1.11642008]
# iteration = 225  weights =  [ 2.79088924 -1.11660478]
# iteration = 226  weights =  [ 2.79099688 -1.11678892]
# iteration = 227  weights =  [ 2.79110419 -1.11697252]
# iteration = 228  weights =  [ 2.79121119 -1.11715557]
# iteration = 229  weights =  [ 2.79131786 -1.11733807]
# iteration = 230  weights =  [ 2.79142421 -1.11752002]
# iteration = 231  weights =  [ 2.79153025 -1.11770143]
# iteration = 232  weights =  [ 2.79163597 -1.1178823 ]
# iteration = 233  weights =  [ 2.79174137 -1.11806262]
# iteration = 234  weights =  [ 2.79184646 -1.11824241]
# iteration = 235  weights =  [ 2.79195123 -1.11842166]
# iteration = 236  weights =  [ 2.79205569 -1.11860038]
# iteration = 237  weights =  [ 2.79215984 -1.11877856]
# iteration = 238  weights =  [ 2.79226367 -1.11895621]
# iteration = 239  weights =  [ 2.7923672  -1.11913332]
# iteration = 240  weights =  [ 2.79247042 -1.11930991]
# iteration = 241  weights =  [ 2.79257332 -1.11948597]
# iteration = 242  weights =  [ 2.79267592 -1.1196615 ]
# iteration = 243  weights =  [ 2.79277822 -1.11983651]
# iteration = 244  weights =  [ 2.79288021 -1.12001099]
# iteration = 245  weights =  [ 2.79298189 -1.12018495]
# iteration = 246  weights =  [ 2.79308327 -1.1203584 ]
# iteration = 247  weights =  [ 2.79318434 -1.12053132]
# iteration = 248  weights =  [ 2.79328512 -1.12070373]
# iteration = 249  weights =  [ 2.79338559 -1.12087562]
# iteration = 250  weights =  [ 2.79348576 -1.121047  ]
# iteration = 251  weights =  [ 2.79358563 -1.12121786]
# iteration = 252  weights =  [ 2.7936852  -1.12138822]
# iteration = 253  weights =  [ 2.79378448 -1.12155806]
# iteration = 254  weights =  [ 2.79388346 -1.1217274 ]
# iteration = 255  weights =  [ 2.79398214 -1.12189623]
# iteration = 256  weights =  [ 2.79408053 -1.12206456]
# iteration = 257  weights =  [ 2.79417862 -1.12223238]
# iteration = 258  weights =  [ 2.79427642 -1.1223997 ]
# iteration = 259  weights =  [ 2.79437393 -1.12256652]
# iteration = 260  weights =  [ 2.79447115 -1.12273284]
# iteration = 261  weights =  [ 2.79456808 -1.12289867]
# iteration = 262  weights =  [ 2.79466471 -1.123064  ]
# iteration = 263  weights =  [ 2.79476106 -1.12322883]
# iteration = 264  weights =  [ 2.79485712 -1.12339317]
# iteration = 265  weights =  [ 2.79495289 -1.12355702]
# iteration = 266  weights =  [ 2.79504838 -1.12372038]
# iteration = 267  weights =  [ 2.79514358 -1.12388326]
# iteration = 268  weights =  [ 2.79523849 -1.12404564]
# iteration = 269  weights =  [ 2.79533312 -1.12420754]
# iteration = 270  weights =  [ 2.79542747 -1.12436896]
# iteration = 271  weights =  [ 2.79552154 -1.12452989]
# iteration = 272  weights =  [ 2.79561532 -1.12469034]
# iteration = 273  weights =  [ 2.79570883 -1.12485031]
# iteration = 274  weights =  [ 2.79580206 -1.12500981]
# iteration = 275  weights =  [ 2.795895   -1.12516883]
# iteration = 276  weights =  [ 2.79598767 -1.12532737]
# iteration = 277  weights =  [ 2.79608006 -1.12548544]
# iteration = 278  weights =  [ 2.79617218 -1.12564303]
# iteration = 279  weights =  [ 2.79626402 -1.12580015]
# iteration = 280  weights =  [ 2.79635558 -1.12595681]
# iteration = 281  weights =  [ 2.79644688 -1.12611299]
# iteration = 282  weights =  [ 2.79653789 -1.12626871]
# iteration = 283  weights =  [ 2.79662864 -1.12642397]
# iteration = 284  weights =  [ 2.79671912 -1.12657876]
# iteration = 285  weights =  [ 2.79680932 -1.12673308]
# iteration = 286  weights =  [ 2.79689926 -1.12688695]
# iteration = 287  weights =  [ 2.79698892 -1.12704035]
# iteration = 288  weights =  [ 2.79707832 -1.1271933 ]
# iteration = 289  weights =  [ 2.79716745 -1.12734579]
# iteration = 290  weights =  [ 2.79725632 -1.12749782]
# iteration = 291  weights =  [ 2.79734492 -1.1276494 ]
# iteration = 292  weights =  [ 2.79743325 -1.12780052]
# iteration = 293  weights =  [ 2.79752132 -1.1279512 ]
# iteration = 294  weights =  [ 2.79760913 -1.12810142]
# iteration = 295  weights =  [ 2.79769667 -1.12825119]
# iteration = 296  weights =  [ 2.79778395 -1.12840052]
# iteration = 297  weights =  [ 2.79787097 -1.1285494 ]
# iteration = 298  weights =  [ 2.79795774 -1.12869783]
# iteration = 299  weights =  [ 2.79804424 -1.12884582]
# iteration = 300  weights =  [ 2.79813048 -1.12899337]
# iteration = 301  weights =  [ 2.79821647 -1.12914048]
# iteration = 302  weights =  [ 2.79830219 -1.12928715]
# iteration = 303  weights =  [ 2.79838767 -1.12943337]
# iteration = 304  weights =  [ 2.79847288 -1.12957917]
# iteration = 305  weights =  [ 2.79855784 -1.12972452]
# iteration = 306  weights =  [ 2.79864255 -1.12986944]
# iteration = 307  weights =  [ 2.798727   -1.13001393]
# iteration = 308  weights =  [ 2.79881121 -1.13015799]
# iteration = 309  weights =  [ 2.79889516 -1.13030161]
# iteration = 310  weights =  [ 2.79897886 -1.13044481]
# iteration = 311  weights =  [ 2.7990623  -1.13058757]
# iteration = 312  weights =  [ 2.7991455  -1.13072991]
# iteration = 313  weights =  [ 2.79922845 -1.13087183]
# iteration = 314  weights =  [ 2.79931116 -1.13101332]
# iteration = 315  weights =  [ 2.79939361 -1.13115439]
# iteration = 316  weights =  [ 2.79947582 -1.13129503]
# iteration = 317  weights =  [ 2.79955778 -1.13143526]
# iteration = 318  weights =  [ 2.7996395  -1.13157506]
# iteration = 319  weights =  [ 2.79972097 -1.13171445]
# iteration = 320  weights =  [ 2.7998022  -1.13185342]
# iteration = 321  weights =  [ 2.79988319 -1.13199198]
# iteration = 322  weights =  [ 2.79996394 -1.13213012]
# iteration = 323  weights =  [ 2.80004444 -1.13226785]
# iteration = 324  weights =  [ 2.8001247  -1.13240517]
# iteration = 325  weights =  [ 2.80020473 -1.13254207]
# iteration = 326  weights =  [ 2.80028451 -1.13267857]
# iteration = 327  weights =  [ 2.80036405 -1.13281466]
# iteration = 328  weights =  [ 2.80044336 -1.13295034]
# iteration = 329  weights =  [ 2.80052243 -1.13308562]
# iteration = 330  weights =  [ 2.80060127 -1.13322049]
# iteration = 331  weights =  [ 2.80067986 -1.13335496]
# iteration = 332  weights =  [ 2.80075823 -1.13348902]
# iteration = 333  weights =  [ 2.80083636 -1.13362269]
# iteration = 334  weights =  [ 2.80091425 -1.13375596]
# iteration = 335  weights =  [ 2.80099191 -1.13388882]
# iteration = 336  weights =  [ 2.80106934 -1.13402129]
# iteration = 337  weights =  [ 2.80114654 -1.13415337]
# iteration = 338  weights =  [ 2.80122351 -1.13428505]
# iteration = 339  weights =  [ 2.80130025 -1.13441633]
# iteration = 340  weights =  [ 2.80137676 -1.13454723]
# iteration = 341  weights =  [ 2.80145303 -1.13467773]
# iteration = 342  weights =  [ 2.80152909 -1.13480784]
# iteration = 343  weights =  [ 2.80160491 -1.13493756]
# iteration = 344  weights =  [ 2.80168051 -1.1350669 ]
# iteration = 345  weights =  [ 2.80175588 -1.13519585]
# iteration = 346  weights =  [ 2.80183102 -1.13532441]
# iteration = 347  weights =  [ 2.80190595 -1.13545259]
# iteration = 348  weights =  [ 2.80198064 -1.13558038]
# iteration = 349  weights =  [ 2.80205512 -1.1357078 ]
# iteration = 350  weights =  [ 2.80212937 -1.13583483]
# iteration = 351  weights =  [ 2.8022034  -1.13596148]
# iteration = 352  weights =  [ 2.80227721 -1.13608775]
# iteration = 353  weights =  [ 2.80235079 -1.13621365]
# iteration = 354  weights =  [ 2.80242416 -1.13633917]
# iteration = 355  weights =  [ 2.80249731 -1.13646431]
# iteration = 356  weights =  [ 2.80257024 -1.13658908]
# iteration = 357  weights =  [ 2.80264295 -1.13671348]
# iteration = 358  weights =  [ 2.80271544 -1.13683751]
# iteration = 359  weights =  [ 2.80278772 -1.13696116]
# iteration = 360  weights =  [ 2.80285978 -1.13708445]
# iteration = 361  weights =  [ 2.80293163 -1.13720736]
# iteration = 362  weights =  [ 2.80300326 -1.13732991]
# iteration = 363  weights =  [ 2.80307467 -1.13745209]
# iteration = 364  weights =  [ 2.80314588 -1.13757391]
# iteration = 365  weights =  [ 2.80321687 -1.13769536]
# iteration = 366  weights =  [ 2.80328764 -1.13781645]
# iteration = 367  weights =  [ 2.80335821 -1.13793718]
# iteration = 368  weights =  [ 2.80342857 -1.13805755]
# iteration = 369  weights =  [ 2.80349871 -1.13817755]
# iteration = 370  weights =  [ 2.80356865 -1.1382972 ]
# iteration = 371  weights =  [ 2.80363837 -1.13841649]
# iteration = 372  weights =  [ 2.80370789 -1.13853542]
# iteration = 373  weights =  [ 2.8037772 -1.138654 ]
# iteration = 374  weights =  [ 2.8038463  -1.13877223]
# iteration = 375  weights =  [ 2.8039152 -1.1388901]
# iteration = 376  weights =  [ 2.80398389 -1.13900761]
# iteration = 377  weights =  [ 2.80405237 -1.13912478]
# iteration = 378  weights =  [ 2.80412065 -1.1392416 ]
# iteration = 379  weights =  [ 2.80418873 -1.13935806]
# iteration = 380  weights =  [ 2.8042566  -1.13947418]
# iteration = 381  weights =  [ 2.80432427 -1.13958995]
# iteration = 382  weights =  [ 2.80439174 -1.13970538]
# iteration = 383  weights =  [ 2.804459   -1.13982046]
# iteration = 384  weights =  [ 2.80452607 -1.13993519]
# iteration = 385  weights =  [ 2.80459293 -1.14004959]
# iteration = 386  weights =  [ 2.80465959 -1.14016364]
# iteration = 387  weights =  [ 2.80472606 -1.14027735]
# iteration = 388  weights =  [ 2.80479232 -1.14039072]
# iteration = 389  weights =  [ 2.80485839 -1.14050375]
# iteration = 390  weights =  [ 2.80492426 -1.14061644]
# iteration = 391  weights =  [ 2.80498993 -1.1407288 ]
# iteration = 392  weights =  [ 2.80505541 -1.14084082]
# iteration = 393  weights =  [ 2.80512069 -1.1409525 ]
# iteration = 394  weights =  [ 2.80518578 -1.14106385]
# iteration = 395  weights =  [ 2.80525067 -1.14117487]
# iteration = 396  weights =  [ 2.80531536 -1.14128556]
# iteration = 397  weights =  [ 2.80537987 -1.14139591]
# iteration = 398  weights =  [ 2.80544418 -1.14150594]
# iteration = 399  weights =  [ 2.8055083  -1.14161564]
# iteration = 400  weights =  [ 2.80557222 -1.141725  ]
# iteration = 401  weights =  [ 2.80563596 -1.14183405]
# iteration = 402  weights =  [ 2.80569951 -1.14194276]
# iteration = 403  weights =  [ 2.80576286 -1.14205115]
# iteration = 404  weights =  [ 2.80582603 -1.14215922]
# iteration = 405  weights =  [ 2.805889   -1.14226696]
# iteration = 406  weights =  [ 2.80595179 -1.14237438]
# iteration = 407  weights =  [ 2.80601439 -1.14248148]
# iteration = 408  weights =  [ 2.80607681 -1.14258826]
# iteration = 409  weights =  [ 2.80613903 -1.14269472]
# iteration = 410  weights =  [ 2.80620108 -1.14280087]
# iteration = 411  weights =  [ 2.80626293 -1.14290669]
# iteration = 412  weights =  [ 2.8063246 -1.1430122]
# iteration = 413  weights =  [ 2.80638609 -1.14311739]
# iteration = 414  weights =  [ 2.80644739 -1.14322227]
# iteration = 415  weights =  [ 2.80650851 -1.14332684]
# iteration = 416  weights =  [ 2.80656945 -1.14343109]
# iteration = 417  weights =  [ 2.8066302  -1.14353503]
# iteration = 418  weights =  [ 2.80669077 -1.14363866]
# iteration = 419  weights =  [ 2.80675116 -1.14374198]
# iteration = 420  weights =  [ 2.80681138 -1.14384499]
# iteration = 421  weights =  [ 2.80687141 -1.1439477 ]
# iteration = 422  weights =  [ 2.80693126 -1.14405009]
# iteration = 423  weights =  [ 2.80699093 -1.14415218]
# iteration = 424  weights =  [ 2.80705042 -1.14425397]
# iteration = 425  weights =  [ 2.80710974 -1.14435545]
# iteration = 426  weights =  [ 2.80716888 -1.14445662]
# iteration = 427  weights =  [ 2.80722784 -1.1445575 ]
# iteration = 428  weights =  [ 2.80728663 -1.14465807]
# iteration = 429  weights =  [ 2.80734524 -1.14475834]
# iteration = 430  weights =  [ 2.80740367 -1.14485832]
# iteration = 431  weights =  [ 2.80746193 -1.14495799]
# iteration = 432  weights =  [ 2.80752002 -1.14505737]
# iteration = 433  weights =  [ 2.80757793 -1.14515644]
# iteration = 434  weights =  [ 2.80763567 -1.14525523]
# iteration = 435  weights =  [ 2.80769324 -1.14535371]
# iteration = 436  weights =  [ 2.80775063 -1.14545191]
# iteration = 437  weights =  [ 2.80780785 -1.1455498 ]
# iteration = 438  weights =  [ 2.8078649  -1.14564741]
# iteration = 439  weights =  [ 2.80792179 -1.14574473]
# iteration = 440  weights =  [ 2.8079785  -1.14584175]
# iteration = 441  weights =  [ 2.80803504 -1.14593848]
# iteration = 442  weights =  [ 2.80809141 -1.14603493]
# iteration = 443  weights =  [ 2.80814761 -1.14613108]
# iteration = 444  weights =  [ 2.80820365 -1.14622695]
# iteration = 445  weights =  [ 2.80825952 -1.14632253]
# iteration = 446  weights =  [ 2.80831522 -1.14641783]
# iteration = 447  weights =  [ 2.80837075 -1.14651284]
# iteration = 448  weights =  [ 2.80842612 -1.14660757]
# iteration = 449  weights =  [ 2.80848133 -1.14670201]
# iteration = 450  weights =  [ 2.80853636 -1.14679617]
# iteration = 451  weights =  [ 2.80859124 -1.14689005]
# iteration = 452  weights =  [ 2.80864595 -1.14698365]
# iteration = 453  weights =  [ 2.80870049 -1.14707697]
# iteration = 454  weights =  [ 2.80875488 -1.14717001]
# iteration = 455  weights =  [ 2.8088091  -1.14726277]
# iteration = 456  weights =  [ 2.80886315 -1.14735526]
# iteration = 457  weights =  [ 2.80891705 -1.14744746]
# iteration = 458  weights =  [ 2.80897079 -1.1475394 ]
# iteration = 459  weights =  [ 2.80902436 -1.14763105]
# iteration = 460  weights =  [ 2.80907777 -1.14772244]
# iteration = 461  weights =  [ 2.80913103 -1.14781355]
# iteration = 462  weights =  [ 2.80918412 -1.14790439]
# iteration = 463  weights =  [ 2.80923706 -1.14799495]
# iteration = 464  weights =  [ 2.80928984 -1.14808525]
# iteration = 465  weights =  [ 2.80934246 -1.14817527]
# iteration = 466  weights =  [ 2.80939492 -1.14826503]
# iteration = 467  weights =  [ 2.80944723 -1.14835452]
# iteration = 468  weights =  [ 2.80949938 -1.14844374]
# iteration = 469  weights =  [ 2.80955138 -1.14853269]
# iteration = 470  weights =  [ 2.80960321 -1.14862138]
# iteration = 471  weights =  [ 2.8096549 -1.1487098]
# iteration = 472  weights =  [ 2.80970643 -1.14879796]
# iteration = 473  weights =  [ 2.8097578  -1.14888586]
# iteration = 474  weights =  [ 2.80980902 -1.14897349]
# iteration = 475  weights =  [ 2.80986009 -1.14906086]
# iteration = 476  weights =  [ 2.80991101 -1.14914797]
# iteration = 477  weights =  [ 2.80996177 -1.14923482]
# iteration = 478  weights =  [ 2.81001238 -1.1493214 ]
# iteration = 479  weights =  [ 2.81006284 -1.14940773]
# iteration = 480  weights =  [ 2.81011315 -1.14949381]
# iteration = 481  weights =  [ 2.81016331 -1.14957962]
# iteration = 482  weights =  [ 2.81021332 -1.14966518]
# iteration = 483  weights =  [ 2.81026318 -1.14975048]
# iteration = 484  weights =  [ 2.81031289 -1.14983553]
# iteration = 485  weights =  [ 2.81036245 -1.14992032]
# iteration = 486  weights =  [ 2.81041187 -1.15000486]
# iteration = 487  weights =  [ 2.81046113 -1.15008915]
# iteration = 488  weights =  [ 2.81051025 -1.15017318]
# iteration = 489  weights =  [ 2.81055923 -1.15025696]
# iteration = 490  weights =  [ 2.81060805 -1.1503405 ]
# iteration = 491  weights =  [ 2.81065673 -1.15042378]
# iteration = 492  weights =  [ 2.81070526 -1.15050681]
# iteration = 493  weights =  [ 2.81075365 -1.1505896 ]
# iteration = 494  weights =  [ 2.8108019  -1.15067214]
# iteration = 495  weights =  [ 2.81085    -1.15075443]
# iteration = 496  weights =  [ 2.81089795 -1.15083647]
# iteration = 497  weights =  [ 2.81094577 -1.15091827]
# iteration = 498  weights =  [ 2.81099344 -1.15099983]
# iteration = 499  weights =  [ 2.81104096 -1.15108114]
# iteration = 500  weights =  [ 2.81108835 -1.15116221]
# iteration = 501  weights =  [ 2.81113559 -1.15124303]
# iteration = 502  weights =  [ 2.81118269 -1.15132362]
# iteration = 503  weights =  [ 2.81122966 -1.15140396]
# iteration = 504  weights =  [ 2.81127648 -1.15148407]
# iteration = 505  weights =  [ 2.81132316 -1.15156393]
# iteration = 506  weights =  [ 2.8113697  -1.15164355]
# iteration = 507  weights =  [ 2.8114161  -1.15172294]
# iteration = 508  weights =  [ 2.81146237 -1.15180209]
# iteration = 509  weights =  [ 2.81150849 -1.151881  ]
# iteration = 510  weights =  [ 2.81155448 -1.15195968]
# iteration = 511  weights =  [ 2.81160033 -1.15203812]
# iteration = 512  weights =  [ 2.81164604 -1.15211633]
# iteration = 513  weights =  [ 2.81169162 -1.1521943 ]
# iteration = 514  weights =  [ 2.81173706 -1.15227204]
# iteration = 515  weights =  [ 2.81178236 -1.15234955]
# iteration = 516  weights =  [ 2.81182753 -1.15242683]
# iteration = 517  weights =  [ 2.81187256 -1.15250387]
# iteration = 518  weights =  [ 2.81191746 -1.15258069]
# iteration = 519  weights =  [ 2.81196223 -1.15265727]
# iteration = 520  weights =  [ 2.81200686 -1.15273363]
# iteration = 521  weights =  [ 2.81205135 -1.15280976]
# iteration = 522  weights =  [ 2.81209572 -1.15288566]
# iteration = 523  weights =  [ 2.81213995 -1.15296133]
# iteration = 524  weights =  [ 2.81218405 -1.15303678]
# iteration = 525  weights =  [ 2.81222802 -1.153112  ]
# iteration = 526  weights =  [ 2.81227185 -1.153187  ]
# iteration = 527  weights =  [ 2.81231556 -1.15326177]
# iteration = 528  weights =  [ 2.81235913 -1.15333632]
# iteration = 529  weights =  [ 2.81240258 -1.15341064]
# iteration = 530  weights =  [ 2.81244589 -1.15348475]
# iteration = 531  weights =  [ 2.81248908 -1.15355863]
# iteration = 532  weights =  [ 2.81253213 -1.15363229]
# iteration = 533  weights =  [ 2.81257506 -1.15370573]
# iteration = 534  weights =  [ 2.81261786 -1.15377895]
# iteration = 535  weights =  [ 2.81266053 -1.15385196]
# iteration = 536  weights =  [ 2.81270307 -1.15392474]
# iteration = 537  weights =  [ 2.81274549 -1.15399731]
# iteration = 538  weights =  [ 2.81278778 -1.15406966]
# iteration = 539  weights =  [ 2.81282994 -1.15414179]
# iteration = 540  weights =  [ 2.81287197 -1.15421371]
# iteration = 541  weights =  [ 2.81291389 -1.15428541]
# iteration = 542  weights =  [ 2.81295567 -1.1543569 ]
# iteration = 543  weights =  [ 2.81299733 -1.15442817]
# iteration = 544  weights =  [ 2.81303887 -1.15449923]
# iteration = 545  weights =  [ 2.81308028 -1.15457008]
# iteration = 546  weights =  [ 2.81312157 -1.15464072]
# iteration = 547  weights =  [ 2.81316273 -1.15471115]
# iteration = 548  weights =  [ 2.81320377 -1.15478136]
# iteration = 549  weights =  [ 2.81324469 -1.15485137]
# iteration = 550  weights =  [ 2.81328549 -1.15492116]
# iteration = 551  weights =  [ 2.81332616 -1.15499075]
# iteration = 552  weights =  [ 2.81336672 -1.15506013]
# iteration = 553  weights =  [ 2.81340715 -1.1551293 ]
# iteration = 554  weights =  [ 2.81344746 -1.15519827]
# iteration = 555  weights =  [ 2.81348765 -1.15526703]
# iteration = 556  weights =  [ 2.81352772 -1.15533558]
# iteration = 557  weights =  [ 2.81356767 -1.15540393]
# iteration = 558  weights =  [ 2.8136075  -1.15547207]
# iteration = 559  weights =  [ 2.81364721 -1.15554001]
# iteration = 560  weights =  [ 2.8136868  -1.15560775]
# iteration = 561  weights =  [ 2.81372628 -1.15567528]
# iteration = 562  weights =  [ 2.81376564 -1.15574262]
# iteration = 563  weights =  [ 2.81380487 -1.15580975]
# iteration = 564  weights =  [ 2.813844   -1.15587668]
# iteration = 565  weights =  [ 2.813883   -1.15594341]
# iteration = 566  weights =  [ 2.81392189 -1.15600994]
# iteration = 567  weights =  [ 2.81396066 -1.15607627]
# iteration = 568  weights =  [ 2.81399932 -1.15614241]
# iteration = 569  weights =  [ 2.81403786 -1.15620834]
# iteration = 570  weights =  [ 2.81407628 -1.15627408]
# iteration = 571  weights =  [ 2.81411459 -1.15633963]
# iteration = 572  weights =  [ 2.81415279 -1.15640497]
# iteration = 573  weights =  [ 2.81419087 -1.15647012]
# iteration = 574  weights =  [ 2.81422884 -1.15653508]
# iteration = 575  weights =  [ 2.81426669 -1.15659984]
# iteration = 576  weights =  [ 2.81430443 -1.15666441]
# iteration = 577  weights =  [ 2.81434206 -1.15672879]
# iteration = 578  weights =  [ 2.81437958 -1.15679297]
# iteration = 579  weights =  [ 2.81441698 -1.15685696]
# iteration = 580  weights =  [ 2.81445427 -1.15692076]
# iteration = 581  weights =  [ 2.81449145 -1.15698437]
# iteration = 582  weights =  [ 2.81452852 -1.15704779]
# iteration = 583  weights =  [ 2.81456548 -1.15711102]
# iteration = 584  weights =  [ 2.81460232 -1.15717406]
# iteration = 585  weights =  [ 2.81463906 -1.15723691]
# iteration = 586  weights =  [ 2.81467569 -1.15729957]
# iteration = 587  weights =  [ 2.81471221 -1.15736205]
# iteration = 588  weights =  [ 2.81474862 -1.15742434]
# iteration = 589  weights =  [ 2.81478492 -1.15748644]
# iteration = 590  weights =  [ 2.81482111 -1.15754836]
# iteration = 591  weights =  [ 2.81485719 -1.15761009]
# iteration = 592  weights =  [ 2.81489317 -1.15767164]
# iteration = 593  weights =  [ 2.81492903 -1.15773301]
# iteration = 594  weights =  [ 2.81496479 -1.15779419]
# iteration = 595  weights =  [ 2.81500045 -1.15785518]
# iteration = 596  weights =  [ 2.815036 -1.157916]
# iteration = 597  weights =  [ 2.81507144 -1.15797663]
# iteration = 598  weights =  [ 2.81510677 -1.15803709]
# iteration = 599  weights =  [ 2.815142   -1.15809736]
# iteration = 600  weights =  [ 2.81517712 -1.15815745]
# iteration = 601  weights =  [ 2.81521214 -1.15821736]
# iteration = 602  weights =  [ 2.81524706 -1.15827709]
# iteration = 603  weights =  [ 2.81528187 -1.15833665]
# iteration = 604  weights =  [ 2.81531657 -1.15839602]
# iteration = 605  weights =  [ 2.81535117 -1.15845522]
# iteration = 606  weights =  [ 2.81538567 -1.15851424]
# iteration = 607  weights =  [ 2.81542007 -1.15857309]
# iteration = 608  weights =  [ 2.81545436 -1.15863176]
# iteration = 609  weights =  [ 2.81548855 -1.15869025]
# iteration = 610  weights =  [ 2.81552264 -1.15874857]
# iteration = 611  weights =  [ 2.81555662 -1.15880671]
# iteration = 612  weights =  [ 2.81559051 -1.15886468]
# iteration = 613  weights =  [ 2.81562429 -1.15892248]
# iteration = 614  weights =  [ 2.81565797 -1.1589801 ]
# iteration = 615  weights =  [ 2.81569155 -1.15903756]
# iteration = 616  weights =  [ 2.81572503 -1.15909484]
# iteration = 617  weights =  [ 2.81575842 -1.15915194]
# iteration = 618  weights =  [ 2.8157917  -1.15920888]
# iteration = 619  weights =  [ 2.81582488 -1.15926565]
# iteration = 620  weights =  [ 2.81585796 -1.15932225]
# iteration = 621  weights =  [ 2.81589094 -1.15937868]
# iteration = 622  weights =  [ 2.81592383 -1.15943494]
# iteration = 623  weights =  [ 2.81595661 -1.15949103]
# iteration = 624  weights =  [ 2.8159893  -1.15954696]
# iteration = 625  weights =  [ 2.81602189 -1.15960271]
# iteration = 626  weights =  [ 2.81605439 -1.1596583 ]
# iteration = 627  weights =  [ 2.81608678 -1.15971373]
# iteration = 628  weights =  [ 2.81611908 -1.15976899]
# iteration = 629  weights =  [ 2.81615128 -1.15982408]
# iteration = 630  weights =  [ 2.81618339 -1.15987901]
# iteration = 631  weights =  [ 2.8162154  -1.15993377]
# iteration = 632  weights =  [ 2.81624731 -1.15998837]
# iteration = 633  weights =  [ 2.81627913 -1.16004281]
# iteration = 634  weights =  [ 2.81631086 -1.16009709]
# iteration = 635  weights =  [ 2.81634249 -1.1601512 ]
# iteration = 636  weights =  [ 2.81637402 -1.16020515]
# iteration = 637  weights =  [ 2.81640546 -1.16025894]
# iteration = 638  weights =  [ 2.81643681 -1.16031257]
# iteration = 639  weights =  [ 2.81646806 -1.16036603]
# iteration = 640  weights =  [ 2.81649922 -1.16041934]
# iteration = 641  weights =  [ 2.81653029 -1.16047249]
# iteration = 642  weights =  [ 2.81656126 -1.16052548]
# iteration = 643  weights =  [ 2.81659214 -1.16057831]
# iteration = 644  weights =  [ 2.81662293 -1.16063099]
# iteration = 645  weights =  [ 2.81665362 -1.1606835 ]
# iteration = 646  weights =  [ 2.81668423 -1.16073586]
# iteration = 647  weights =  [ 2.81671474 -1.16078806]
# iteration = 648  weights =  [ 2.81674516 -1.16084011]
# iteration = 649  weights =  [ 2.81677549 -1.160892  ]
# iteration = 650  weights =  [ 2.81680573 -1.16094374]
# iteration = 651  weights =  [ 2.81683588 -1.16099532]
# iteration = 652  weights =  [ 2.81686594 -1.16104675]
# iteration = 653  weights =  [ 2.81689591 -1.16109802]
# iteration = 654  weights =  [ 2.81692579 -1.16114914]
# iteration = 655  weights =  [ 2.81695558 -1.16120011]
# iteration = 656  weights =  [ 2.81698528 -1.16125092]
# iteration = 657  weights =  [ 2.8170149  -1.16130158]
# iteration = 658  weights =  [ 2.81704442 -1.16135209]
# iteration = 659  weights =  [ 2.81707386 -1.16140245]
# iteration = 660  weights =  [ 2.81710321 -1.16145266]
# iteration = 661  weights =  [ 2.81713247 -1.16150272]
# iteration = 662  weights =  [ 2.81716164 -1.16155263]
# iteration = 663  weights =  [ 2.81719072 -1.16160239]
# iteration = 664  weights =  [ 2.81721972 -1.16165201]
# iteration = 665  weights =  [ 2.81724863 -1.16170147]
# iteration = 666  weights =  [ 2.81727746 -1.16175079]
# iteration = 667  weights =  [ 2.8173062  -1.16179995]
# iteration = 668  weights =  [ 2.81733485 -1.16184897]
# iteration = 669  weights =  [ 2.81736342 -1.16189785]
# iteration = 670  weights =  [ 2.8173919  -1.16194658]
# iteration = 671  weights =  [ 2.8174203  -1.16199516]
# iteration = 672  weights =  [ 2.81744861 -1.1620436 ]
# iteration = 673  weights =  [ 2.81747684 -1.16209189]
# iteration = 674  weights =  [ 2.81750498 -1.16214004]
# iteration = 675  weights =  [ 2.81753304 -1.16218804]
# iteration = 676  weights =  [ 2.81756102 -1.1622359 ]
# iteration = 677  weights =  [ 2.81758891 -1.16228362]
# iteration = 678  weights =  [ 2.81761671 -1.1623312 ]
# iteration = 679  weights =  [ 2.81764444 -1.16237863]
# iteration = 680  weights =  [ 2.81767208 -1.16242592]
# iteration = 681  weights =  [ 2.81769964 -1.16247307]
# iteration = 682  weights =  [ 2.81772712 -1.16252008]
# iteration = 683  weights =  [ 2.81775451 -1.16256695]
# iteration = 684  weights =  [ 2.81778183 -1.16261368]
# iteration = 685  weights =  [ 2.81780906 -1.16266026]
# iteration = 686  weights =  [ 2.81783621 -1.16270671]
# iteration = 687  weights =  [ 2.81786328 -1.16275302]
# iteration = 688  weights =  [ 2.81789026 -1.16279919]
# iteration = 689  weights =  [ 2.81791717 -1.16284523]
# iteration = 690  weights =  [ 2.817944   -1.16289112]
# iteration = 691  weights =  [ 2.81797074 -1.16293688]
# iteration = 692  weights =  [ 2.81799741 -1.1629825 ]
# iteration = 693  weights =  [ 2.818024   -1.16302799]
# iteration = 694  weights =  [ 2.8180505  -1.16307334]
# iteration = 695  weights =  [ 2.81807693 -1.16311855]
# iteration = 696  weights =  [ 2.81810328 -1.16316363]
# iteration = 697  weights =  [ 2.81812955 -1.16320858]
# iteration = 698  weights =  [ 2.81815574 -1.16325339]
# iteration = 699  weights =  [ 2.81818186 -1.16329806]
# iteration = 700  weights =  [ 2.81820789 -1.1633426 ]
# iteration = 701  weights =  [ 2.81823385 -1.16338701]
# iteration = 702  weights =  [ 2.81825973 -1.16343129]
# iteration = 703  weights =  [ 2.81828553 -1.16347543]
# iteration = 704  weights =  [ 2.81831126 -1.16351944]
# iteration = 705  weights =  [ 2.8183369  -1.16356332]
# iteration = 706  weights =  [ 2.81836248 -1.16360707]
# iteration = 707  weights =  [ 2.81838797 -1.16365069]
# iteration = 708  weights =  [ 2.81841339 -1.16369418]
# iteration = 709  weights =  [ 2.81843873 -1.16373754]
# iteration = 710  weights =  [ 2.818464   -1.16378077]
# iteration = 711  weights =  [ 2.81848919 -1.16382386]
# iteration = 712  weights =  [ 2.81851431 -1.16386683]
# iteration = 713  weights =  [ 2.81853935 -1.16390968]
# iteration = 714  weights =  [ 2.81856432 -1.16395239]
# iteration = 715  weights =  [ 2.81858921 -1.16399498]
# iteration = 716  weights =  [ 2.81861402 -1.16403743]
# iteration = 717  weights =  [ 2.81863877 -1.16407977]
# iteration = 718  weights =  [ 2.81866344 -1.16412197]
# iteration = 719  weights =  [ 2.81868803 -1.16416405]
# iteration = 720  weights =  [ 2.81871255 -1.164206  ]
# iteration = 721  weights =  [ 2.818737   -1.16424783]
# iteration = 722  weights =  [ 2.81876138 -1.16428953]
# iteration = 723  weights =  [ 2.81878568 -1.16433111]
# iteration = 724  weights =  [ 2.81880991 -1.16437256]
# iteration = 725  weights =  [ 2.81883407 -1.16441389]
# iteration = 726  weights =  [ 2.81885815 -1.1644551 ]
# iteration = 727  weights =  [ 2.81888217 -1.16449618]
# iteration = 728  weights =  [ 2.81890611 -1.16453714]
# iteration = 729  weights =  [ 2.81892998 -1.16457798]
# iteration = 730  weights =  [ 2.81895378 -1.16461869]
# iteration = 731  weights =  [ 2.8189775  -1.16465929]
# iteration = 732  weights =  [ 2.81900116 -1.16469976]
# iteration = 733  weights =  [ 2.81902475 -1.16474011]
# iteration = 734  weights =  [ 2.81904826 -1.16478034]
# iteration = 735  weights =  [ 2.81907171 -1.16482045]
# iteration = 736  weights =  [ 2.81909508 -1.16486044]
# iteration = 737  weights =  [ 2.81911838 -1.16490031]
# iteration = 738  weights =  [ 2.81914162 -1.16494007]
# iteration = 739  weights =  [ 2.81916479 -1.1649797 ]
# iteration = 740  weights =  [ 2.81918788 -1.16501921]
# iteration = 741  weights =  [ 2.81921091 -1.16505861]
# iteration = 742  weights =  [ 2.81923387 -1.16509789]
# iteration = 743  weights =  [ 2.81925676 -1.16513705]
# iteration = 744  weights =  [ 2.81927958 -1.16517609]
# iteration = 745  weights =  [ 2.81930233 -1.16521502]
# iteration = 746  weights =  [ 2.81932502 -1.16525383]
# iteration = 747  weights =  [ 2.81934764 -1.16529252]
# iteration = 748  weights =  [ 2.81937018 -1.1653311 ]
# iteration = 749  weights =  [ 2.81939267 -1.16536957]
# iteration = 750  weights =  [ 2.81941508 -1.16540792]
# iteration = 751  weights =  [ 2.81943743 -1.16544615]
# iteration = 752  weights =  [ 2.81945971 -1.16548427]
# iteration = 753  weights =  [ 2.81948193 -1.16552227]
# iteration = 754  weights =  [ 2.81950407 -1.16556017]
# iteration = 755  weights =  [ 2.81952616 -1.16559795]
# iteration = 756  weights =  [ 2.81954817 -1.16563561]
# iteration = 757  weights =  [ 2.81957012 -1.16567316]
# iteration = 758  weights =  [ 2.81959201 -1.16571061]
# iteration = 759  weights =  [ 2.81961383 -1.16574793]
# iteration = 760  weights =  [ 2.81963558 -1.16578515]
# iteration = 761  weights =  [ 2.81965727 -1.16582226]
# iteration = 762  weights =  [ 2.81967889 -1.16585925]
# iteration = 763  weights =  [ 2.81970045 -1.16589614]
# iteration = 764  weights =  [ 2.81972195 -1.16593291]
# iteration = 765  weights =  [ 2.81974338 -1.16596958]
# iteration = 766  weights =  [ 2.81976474 -1.16600613]
# iteration = 767  weights =  [ 2.81978605 -1.16604258]
# iteration = 768  weights =  [ 2.81980729 -1.16607891]
# iteration = 769  weights =  [ 2.81982846 -1.16611514]
# iteration = 770  weights =  [ 2.81984957 -1.16615126]
# iteration = 771  weights =  [ 2.81987062 -1.16618727]
# iteration = 772  weights =  [ 2.81989161 -1.16622318]
# iteration = 773  weights =  [ 2.81991253 -1.16625897]
# iteration = 774  weights =  [ 2.81993339 -1.16629466]
# iteration = 775  weights =  [ 2.81995419 -1.16633025]
# iteration = 776  weights =  [ 2.81997493 -1.16636572]
# iteration = 777  weights =  [ 2.8199956  -1.16640109]
# iteration = 778  weights =  [ 2.82001621 -1.16643636]
# iteration = 779  weights =  [ 2.82003677 -1.16647152]
# iteration = 780  weights =  [ 2.82005725 -1.16650657]
# iteration = 781  weights =  [ 2.82007768 -1.16654152]
# iteration = 782  weights =  [ 2.82009805 -1.16657636]
# iteration = 783  weights =  [ 2.82011836 -1.1666111 ]
# iteration = 784  weights =  [ 2.8201386  -1.16664574]
# iteration = 785  weights =  [ 2.82015879 -1.16668027]
# iteration = 786  weights =  [ 2.82017891 -1.1667147 ]
# iteration = 787  weights =  [ 2.82019898 -1.16674903]
# iteration = 788  weights =  [ 2.82021898 -1.16678326]
# iteration = 789  weights =  [ 2.82023892 -1.16681738]
# iteration = 790  weights =  [ 2.82025881 -1.1668514 ]
# iteration = 791  weights =  [ 2.82027863 -1.16688532]
# iteration = 792  weights =  [ 2.8202984  -1.16691913]
# iteration = 793  weights =  [ 2.82031811 -1.16695285]
# iteration = 794  weights =  [ 2.82033776 -1.16698646]
# iteration = 795  weights =  [ 2.82035735 -1.16701998]
# iteration = 796  weights =  [ 2.82037688 -1.16705339]
# iteration = 797  weights =  [ 2.82039635 -1.16708671]
# iteration = 798  weights =  [ 2.82041576 -1.16711992]
# iteration = 799  weights =  [ 2.82043512 -1.16715304]
# iteration = 800  weights =  [ 2.82045442 -1.16718605]
# iteration = 801  weights =  [ 2.82047366 -1.16721897]
# iteration = 802  weights =  [ 2.82049284 -1.16725179]
# iteration = 803  weights =  [ 2.82051197 -1.16728451]
# iteration = 804  weights =  [ 2.82053104 -1.16731713]
# iteration = 805  weights =  [ 2.82055005 -1.16734966]
# iteration = 806  weights =  [ 2.820569   -1.16738209]
# iteration = 807  weights =  [ 2.8205879  -1.16741442]
# iteration = 808  weights =  [ 2.82060674 -1.16744665]
# iteration = 809  weights =  [ 2.82062553 -1.16747879]
# iteration = 810  weights =  [ 2.82064426 -1.16751084]
# iteration = 811  weights =  [ 2.82066293 -1.16754278]
# iteration = 812  weights =  [ 2.82068155 -1.16757463]
# iteration = 813  weights =  [ 2.82070011 -1.16760639]
# iteration = 814  weights =  [ 2.82071861 -1.16763805]
# iteration = 815  weights =  [ 2.82073707 -1.16766962]
# iteration = 816  weights =  [ 2.82075546 -1.16770109]
# iteration = 817  weights =  [ 2.8207738  -1.16773247]
# iteration = 818  weights =  [ 2.82079209 -1.16776375]
# iteration = 819  weights =  [ 2.82081032 -1.16779494]
# iteration = 820  weights =  [ 2.82082849 -1.16782604]
# iteration = 821  weights =  [ 2.82084662 -1.16785704]
# iteration = 822  weights =  [ 2.82086469 -1.16788795]
# iteration = 823  weights =  [ 2.8208827  -1.16791877]
# iteration = 824  weights =  [ 2.82090066 -1.1679495 ]
# iteration = 825  weights =  [ 2.82091857 -1.16798014]
# iteration = 826  weights =  [ 2.82093642 -1.16801068]
# iteration = 827  weights =  [ 2.82095422 -1.16804113]
# iteration = 828  weights =  [ 2.82097196 -1.16807149]
# iteration = 829  weights =  [ 2.82098966 -1.16810176]
# iteration = 830  weights =  [ 2.8210073  -1.16813194]
# iteration = 831  weights =  [ 2.82102489 -1.16816203]
# iteration = 832  weights =  [ 2.82104242 -1.16819203]
# iteration = 833  weights =  [ 2.8210599  -1.16822194]
# iteration = 834  weights =  [ 2.82107733 -1.16825176]
# iteration = 835  weights =  [ 2.82109471 -1.16828149]
# iteration = 836  weights =  [ 2.82111204 -1.16831114]
# iteration = 837  weights =  [ 2.82112931 -1.16834069]
# iteration = 838  weights =  [ 2.82114654 -1.16837016]
# iteration = 839  weights =  [ 2.82116371 -1.16839953]
# iteration = 840  weights =  [ 2.82118083 -1.16842882]
# iteration = 841  weights =  [ 2.8211979  -1.16845802]
# iteration = 842  weights =  [ 2.82121491 -1.16848714]
# iteration = 843  weights =  [ 2.82123188 -1.16851617]
# iteration = 844  weights =  [ 2.8212488  -1.16854511]
# iteration = 845  weights =  [ 2.82126566 -1.16857396]
# iteration = 846  weights =  [ 2.82128248 -1.16860273]
# iteration = 847  weights =  [ 2.82129924 -1.16863141]
# iteration = 848  weights =  [ 2.82131596 -1.16866001]
# iteration = 849  weights =  [ 2.82133262 -1.16868852]
# iteration = 850  weights =  [ 2.82134924 -1.16871695]
# iteration = 851  weights =  [ 2.8213658  -1.16874529]
# iteration = 852  weights =  [ 2.82138232 -1.16877354]
# iteration = 853  weights =  [ 2.82139879 -1.16880171]
# iteration = 854  weights =  [ 2.8214152 -1.1688298]
# iteration = 855  weights =  [ 2.82143157 -1.1688578 ]
# iteration = 856  weights =  [ 2.82144789 -1.16888572]
# iteration = 857  weights =  [ 2.82146416 -1.16891356]
# iteration = 858  weights =  [ 2.82148038 -1.16894131]
# iteration = 859  weights =  [ 2.82149655 -1.16896898]
# iteration = 860  weights =  [ 2.82151268 -1.16899657]
# iteration = 861  weights =  [ 2.82152876 -1.16902407]
# iteration = 862  weights =  [ 2.82154478 -1.1690515 ]
# iteration = 863  weights =  [ 2.82156077 -1.16907884]
# iteration = 864  weights =  [ 2.8215767  -1.16910609]
# iteration = 865  weights =  [ 2.82159258 -1.16913327]
# iteration = 866  weights =  [ 2.82160842 -1.16916037]
# iteration = 867  weights =  [ 2.82162421 -1.16918738]
# iteration = 868  weights =  [ 2.82163995 -1.16921432]
# iteration = 869  weights =  [ 2.82165565 -1.16924117]
# iteration = 870  weights =  [ 2.8216713  -1.16926794]
# iteration = 871  weights =  [ 2.8216869  -1.16929464]
# iteration = 872  weights =  [ 2.82170246 -1.16932125]
# iteration = 873  weights =  [ 2.82171797 -1.16934778]
# iteration = 874  weights =  [ 2.82173343 -1.16937424]
# iteration = 875  weights =  [ 2.82174885 -1.16940061]
# iteration = 876  weights =  [ 2.82176422 -1.16942691]
# iteration = 877  weights =  [ 2.82177954 -1.16945313]
# iteration = 878  weights =  [ 2.82179482 -1.16947927]
# iteration = 879  weights =  [ 2.82181005 -1.16950533]
# iteration = 880  weights =  [ 2.82182524 -1.16953131]
# iteration = 881  weights =  [ 2.82184038 -1.16955722]
# iteration = 882  weights =  [ 2.82185548 -1.16958305]
# iteration = 883  weights =  [ 2.82187053 -1.1696088 ]
# iteration = 884  weights =  [ 2.82188554 -1.16963447]
# iteration = 885  weights =  [ 2.8219005  -1.16966007]
# iteration = 886  weights =  [ 2.82191542 -1.16968559]
# iteration = 887  weights =  [ 2.82193029 -1.16971103]
# iteration = 888  weights =  [ 2.82194512 -1.1697364 ]
# iteration = 889  weights =  [ 2.8219599 -1.1697617]
# iteration = 890  weights =  [ 2.82197464 -1.16978691]
# iteration = 891  weights =  [ 2.82198934 -1.16981205]
# iteration = 892  weights =  [ 2.82200399 -1.16983712]
# iteration = 893  weights =  [ 2.8220186  -1.16986211]
# iteration = 894  weights =  [ 2.82203316 -1.16988703]
# iteration = 895  weights =  [ 2.82204768 -1.16991187]
# iteration = 896  weights =  [ 2.82206216 -1.16993664]
# iteration = 897  weights =  [ 2.82207659 -1.16996133]
# iteration = 898  weights =  [ 2.82209098 -1.16998595]
# iteration = 899  weights =  [ 2.82210533 -1.1700105 ]
# iteration = 900  weights =  [ 2.82211964 -1.17003497]
# iteration = 901  weights =  [ 2.8221339  -1.17005937]
# iteration = 902  weights =  [ 2.82214812 -1.1700837 ]
# iteration = 903  weights =  [ 2.82216229 -1.17010795]
# iteration = 904  weights =  [ 2.82217643 -1.17013214]
# iteration = 905  weights =  [ 2.82219052 -1.17015625]
# iteration = 906  weights =  [ 2.82220457 -1.17018028]
# iteration = 907  weights =  [ 2.82221858 -1.17020425]
# iteration = 908  weights =  [ 2.82223254 -1.17022814]
# iteration = 909  weights =  [ 2.82224647 -1.17025196]
# iteration = 910  weights =  [ 2.82226035 -1.17027572]
# iteration = 911  weights =  [ 2.82227419 -1.1702994 ]
# iteration = 912  weights =  [ 2.82228799 -1.170323  ]
# iteration = 913  weights =  [ 2.82230175 -1.17034654]
# iteration = 914  weights =  [ 2.82231547 -1.17037001]
# iteration = 915  weights =  [ 2.82232915 -1.17039341]
# iteration = 916  weights =  [ 2.82234278 -1.17041674]
# iteration = 917  weights =  [ 2.82235638 -1.17044   ]
# iteration = 918  weights =  [ 2.82236993 -1.17046319]
# iteration = 919  weights =  [ 2.82238344 -1.17048631]
# iteration = 920  weights =  [ 2.82239692 -1.17050936]
# iteration = 921  weights =  [ 2.82241035 -1.17053234]
# iteration = 922  weights =  [ 2.82242374 -1.17055525]
# iteration = 923  weights =  [ 2.82243709 -1.1705781 ]
# iteration = 924  weights =  [ 2.82245041 -1.17060087]
# iteration = 925  weights =  [ 2.82246368 -1.17062358]
# iteration = 926  weights =  [ 2.82247691 -1.17064622]
# iteration = 927  weights =  [ 2.82249011 -1.17066879]
# iteration = 928  weights =  [ 2.82250326 -1.1706913 ]
# iteration = 929  weights =  [ 2.82251638 -1.17071373]
# iteration = 930  weights =  [ 2.82252945 -1.1707361 ]
# iteration = 931  weights =  [ 2.82254249 -1.17075841]
# iteration = 932  weights =  [ 2.82255549 -1.17078065]
# iteration = 933  weights =  [ 2.82256845 -1.17080282]
# iteration = 934  weights =  [ 2.82258137 -1.17082492]
# iteration = 935  weights =  [ 2.82259425 -1.17084696]
# iteration = 936  weights =  [ 2.82260709 -1.17086893]
# iteration = 937  weights =  [ 2.8226199  -1.17089084]
# iteration = 938  weights =  [ 2.82263266 -1.17091268]
# iteration = 939  weights =  [ 2.82264539 -1.17093445]
# iteration = 940  weights =  [ 2.82265808 -1.17095616]
# iteration = 941  weights =  [ 2.82267073 -1.17097781]
# iteration = 942  weights =  [ 2.82268335 -1.17099939]
# iteration = 943  weights =  [ 2.82269592 -1.17102091]
# iteration = 944  weights =  [ 2.82270846 -1.17104236]
# iteration = 945  weights =  [ 2.82272096 -1.17106375]
# iteration = 946  weights =  [ 2.82273343 -1.17108507]
# iteration = 947  weights =  [ 2.82274585 -1.17110633]
# iteration = 948  weights =  [ 2.82275824 -1.17112753]
# iteration = 949  weights =  [ 2.8227706  -1.17114866]
# iteration = 950  weights =  [ 2.82278291 -1.17116973]
# iteration = 951  weights =  [ 2.82279519 -1.17119074]
# iteration = 952  weights =  [ 2.82280743 -1.17121168]
# iteration = 953  weights =  [ 2.82281964 -1.17123257]
# iteration = 954  weights =  [ 2.82283181 -1.17125339]
# iteration = 955  weights =  [ 2.82284394 -1.17127414]
# iteration = 956  weights =  [ 2.82285604 -1.17129484]
# iteration = 957  weights =  [ 2.8228681  -1.17131547]
# iteration = 958  weights =  [ 2.82288012 -1.17133604]
# iteration = 959  weights =  [ 2.82289211 -1.17135655]
# iteration = 960  weights =  [ 2.82290406 -1.171377  ]
# iteration = 961  weights =  [ 2.82291598 -1.17139739]
# iteration = 962  weights =  [ 2.82292786 -1.17141772]
# iteration = 963  weights =  [ 2.82293971 -1.17143798]
# iteration = 964  weights =  [ 2.82295152 -1.17145819]
# iteration = 965  weights =  [ 2.82296329 -1.17147833]
# iteration = 966  weights =  [ 2.82297503 -1.17149842]
# iteration = 967  weights =  [ 2.82298673 -1.17151844]
# iteration = 968  weights =  [ 2.8229984 -1.1715384]
# iteration = 969  weights =  [ 2.82301004 -1.17155831]
# iteration = 970  weights =  [ 2.82302164 -1.17157815]
# iteration = 971  weights =  [ 2.8230332  -1.17159794]
# iteration = 972  weights =  [ 2.82304473 -1.17161767]
# iteration = 973  weights =  [ 2.82305623 -1.17163734]
# iteration = 974  weights =  [ 2.82306769 -1.17165695]
# iteration = 975  weights =  [ 2.82307912 -1.1716765 ]
# iteration = 976  weights =  [ 2.82309051 -1.17169599]
# iteration = 977  weights =  [ 2.82310187 -1.17171542]
# iteration = 978  weights =  [ 2.8231132 -1.1717348]
# iteration = 979  weights =  [ 2.82312449 -1.17175411]
# iteration = 980  weights =  [ 2.82313575 -1.17177337]
# iteration = 981  weights =  [ 2.82314697 -1.17179258]
# iteration = 982  weights =  [ 2.82315816 -1.17181172]
# iteration = 983  weights =  [ 2.82316932 -1.17183081]
# iteration = 984  weights =  [ 2.82318044 -1.17184984]
# iteration = 985  weights =  [ 2.82319153 -1.17186881]
# iteration = 986  weights =  [ 2.82320259 -1.17188773]
# iteration = 987  weights =  [ 2.82321361 -1.17190659]
# iteration = 988  weights =  [ 2.8232246 -1.1719254]
# iteration = 989  weights =  [ 2.82323556 -1.17194414]
# iteration = 990  weights =  [ 2.82324649 -1.17196284]
# iteration = 991  weights =  [ 2.82325738 -1.17198147]
# iteration = 992  weights =  [ 2.82326824 -1.17200005]
# iteration = 993  weights =  [ 2.82327907 -1.17201858]
# iteration = 994  weights =  [ 2.82328986 -1.17203705]
# iteration = 995  weights =  [ 2.82330063 -1.17205546]
# iteration = 996  weights =  [ 2.82331136 -1.17207382]
# iteration = 997  weights =  [ 2.82332206 -1.17209212]
# iteration = 998  weights =  [ 2.82333272 -1.17211037]
# iteration = 999  weights =  [ 2.82334336 -1.17212857]

# %%
# test
print(f"input={X[1]},\npredicted={np.dot(weights, X[1])}\nactual = {Y[1]}\nerror = {np.dot(weights, X[1]) - Y[1]}\nerror %age = {round(abs((np.dot(weights, X[1]) - Y[1] - Y[1]) / Y[1]) * 100 ,2)}% ")
# Out:
# input=[2 1],
# predicted=4.474558150142222
# actual = 3.2
# error = 1.274558150142222
# error %age = 60.17%
