# %% [markdown]
# # Complete Neuron

# %% [markdown]
# ## Perameters
#
# - `learning_rate`
# - `activation`
# - `loss`
# - `optimizer`

# %%
#
# Imports
#

import numpy as np
from collections.abc import Iterable
from numbers import Number

# %%
#
# Customer Exceptions
#

class InvalidInitialWeights(Exception): pass

class UnexpectedInputsShape(Exception): pass
class UnexpectedOutputsShape(Exception): pass

class InvalidActivation(Exception): pass
class InvalidOptimizer(Exception): pass
class InvalidLoss(Exception): pass

# %%
#
# Sigmoid Activation
#

class Sigmoid():

  def apply(self, x):
    return 1 / (1 + np.exp(-x))
  
  def derivative(self, x):
    sig = self.apply(x)
    return sig * (1 - sig)

# %%
#
# Mean Squared Error
#

class MeanSquaredError():
  N = 0

  def calculate(self, y_true:Iterable, y_pred:Iterable):
    self.N = len(y_true)
    return np.mean(np.square(y_true - y_pred))
  
  def derivative(self, y_true:Number, y_pred:Number):
    return -2*(y_true-y_pred)/self.N

# %%
#
# Stochastic Gradient Descent
#

class StochasticGradientDescent():
  def __init__(self, learning_rate=None):
    self.learning_rate = learning_rate

  def update(self, model, learning_rate=0.01):
    # learning rate
    lr = self.learning_rate or model.learning_rate or learning_rate

    # hierarchy functions
    def update_neuron(neuron, lr): neuron.update(lr)
    def update_layer(layer, lr):
      for neuron in layer.neurons: update_neuron(neuron, lr)

    # if ann
    if hasattr(model, 'layers'):
      for layer in model.layers: update_layer(layer, lr)
    
    # if layer
    elif hasattr(model, 'neurons'):
      for neuron in model.neurons: update_neuron(neuron, lr)
    
    # if neuron
    elif hasattr(model, 'forward'):
      update_neuron(model, lr)

# %%
class Neuron():

  # 
  # Props
  # 

  builtin:dict = {
    'activation': {
      'default': Sigmoid,
      'sigmoid': Sigmoid,
    },
    'loss_function': {
      'default': MeanSquaredError,
      'sigmoid': MeanSquaredError,
    },
    'optimizer': {
      'default': StochasticGradientDescent,
      'sgd': StochasticGradientDescent,
    }
  }

  errors:dict = {
    'activation':    InvalidActivation,
    'loss_function': InvalidLoss,
    'optimizer':     InvalidOptimizer,
  }

  input:Iterable = []
  output:float = 0.0

  delta:float = 0.0


  weight_gradient:Iterable = []
  bias_gradient:float = 0.0



  # 
  # Constructor
  # 

  def __init__(
      self,

      input_size:int,
      
      learning_rate:float=0.1,
      activation:str|object='default',
      loss_function:str|object='default',
      optimizer:str|object='default',

      initial_weights:Number|Iterable=0,
      initial_bias:Number=0,
      debug:bool=True
    ):
    self.debug = debug

    #> input size and learning rate

    # Input Size
    self.input_size = input_size
    self.input = np.repeat(0, self.input_size)
    
    # Learning Rate
    self.learning_rate = learning_rate

    #> activation, loss_function and optimizer

    params = {
      'activation':    activation,
      'loss_function': loss_function,
      'optimizer':     optimizer,
    }

    # iterate all
    for target in ['activation', 'loss_function', 'optimizer']:

      # get param
      param = params[target]
      
      # if object, set directly
      if type(param) == object: setattr(self, target, param)

      # if present in builtin, set
      elif type(param) == str and param in self.builtin[target].keys():
        setattr(self, target, self.builtin[target][param]())

      # raise error
      # if not in {object, str} or string and not in builtin
      else: raise self.errors[target](param)


    #> Initial Weights & Bias

    # initial weights
    if isinstance(initial_weights, Number):                                            self.weights = np.repeat(initial_weights, input_size).astype(float)
    elif isinstance(initial_weights, Iterable) and len(initial_weights) == input_size: self.weights = np.array(initial_weights).astype(float)
    else: raise InvalidInitialWeights(f'Value must be either a number or an Iterable of size {input_size}')

    # initialize gradient to zero
    self.weight_gradient = np.repeat(0.0, self.input_size)

    # initial bias
    self.bias = initial_bias

    if self.debug:
      print('initial')
      print('=======')
      print(f'weights={self.weights},\nbias={self.bias},\nlearning_rate={self.learning_rate}\n')


  
  #
  # Forward
  #

  def forward(self, input):
    self.input = np.array(input)

    # if 1d, predict
    if len(self.input.shape) and self.input.shape[0] == self.input_size:
      # weighted sum
      weighted_sum = np.dot(self.input, self.weights) + self.bias

      # activation
      self.output = self.activation.apply(weighted_sum)

      if self.debug: print(f'[DEBUG] input={input}, weighted_sum={weighted_sum}, predicted={self.output}')

      # return
      return self.output
    
    # elif 2d, predict multiple
    return self.forward_multiple(self.input)



  #
  # Forward Multiple samples
  #

  def forward_multiple(self, inputs):
    inputs = np.array(inputs)

    if len(inputs.shape) < 2 or inputs.shape[1] != self.input_size:
      raise UnexpectedInputsShape(f'Inputs shape must be (n, {self.input_size}). found {inputs.shape}')

    results = []
    for inp in inputs:
      results.append(self.forward(inp))

    return np.array(results)



  #
  # Backward Pass (loss & optimize)
  #

  def backward(self, error=None):
    self.error = error or self.error

    # gradient
    self.delta = self.error * self.activation.derivative(self.output)

    # gradients for weights and bias
    self.weight_gradient = self.delta * self.input
    self.bias_gradient = self.delta

    if self.debug: print(f'[DEBUG] delta={self.delta}, w_grad={self.weight_gradient}, b_grad={self.bias_gradient}')

    # return loss for previous neurons
    return np.dot(self.delta, self.weights)


  def update(self, learning_rate=None):
    lr = learning_rate or self.learning_rate

    if self.debug: print(f'[DEBUG] lr={lr}')

    if self.debug: print(f'[DEBUG] w_before={self.weights}, b_before={self.bias}')

    self.weights -= self.weight_gradient * lr
    self.bias    -= self.bias_gradient * lr

    if self.debug: print(f'[DEBUG] w_after={self.weights}, b_after={self.bias}')



  #
  # Train
  #

  def train(self, inputs:Iterable, outputs:Iterable, epochs:int=100, verbose:int=1):
    inputs = np.array(inputs)
    outputs = np.array(outputs)

    if len(inputs.shape) < 2 or inputs.shape[1] != self.input_size:    raise UnexpectedInputsShape (f'Inputs shape must be (n, {self.input_size}). found {inputs.shape}')
    if len(outputs.shape) != 1 or outputs.shape[0] != inputs.shape[0]: raise UnexpectedOutputsShape(f'Outputs size ({outputs.shape[0]}) differs from no of samples in input ({inputs.shape[0]})')
    
    for e in range(epochs):
      
      predicted = []
      
      for i in range(outputs.shape[0]):

        # Forward Pass
        self.forward(inputs[i])
        predicted.append(self.output)

        # error calculation
        self.error = self.output - outputs[i]

        if self.debug: print(f'[DEBUG] epoch={e+1}, sample={i+1}, actual={outputs[i]}, predicted={self.output}, error={self.error}')

        # Backward Pass
        self.backward()

        # Weights Updation
        self.optimizer.update(self)

        if verbose > 1: print(f'epoch={e+1}, sample={i+1}, actual={outputs[i]}, predicted={self.output}, error={self.error}')
      

      # Loss Calculation
      self.loss = self.loss_function.calculate(outputs, predicted)

      if verbose: print(f'epoch={e+1}, loss={self.loss}')



  #
  # Test
  #

  def test(self, inputs:Iterable, outputs:Iterable, verbose:int=0):
    inputs = np.array(inputs)
    outputs = np.array(outputs)

    if len(inputs.shape) < 2 or inputs.shape[1] != self.input_size:    raise UnexpectedInputsShape (f'Inputs shape must be (n, {self.input_size}). found {inputs.shape}')
    if len(outputs.shape) != 1 or outputs.shape[0] != inputs.shape[0]: raise UnexpectedOutputsShape(f'Outputs size ({outputs.shape[0]}) differs from no of samples in input ({inputs.shape[0]})')
    

    accurate = 0
    wrong    = 0
    for i in range(inputs.shape[0]):

      # Forward Pass
      predicted = self.forward(inputs[i])

      if predicted == outputs[i]: accurate+=1
      else:                       wrong   +=1

      if verbose > 1: print(f'sample={i+1}, predicted={predicted}, actual={outputs[i]}, error={outputs[i] - predicted}')

    return {
      'total':    accurate + wrong,
      'accurate': accurate,
      'wrong':    wrong,
    }

# %% [markdown]
# ## Usage

# %%
# load dataset
from dataset import X, Y
X.shape
# Out:
# (10, 3)

# %% [markdown]
# #### Minimal

# %%
neuron = Neuron(3)
# Out:
# initial
# =======
# weights=[0. 0. 0.],
# bias=0,
# learning_rate=0.1

# %%
neuron.train(X, Y)
# Out:
# [DEBUG] input=[10 15  1], weighted_sum=0.0, predicted=0.5
# [DEBUG] epoch=1, sample=1, actual=1, predicted=0.5, error=-0.5
# [DEBUG] delta=-0.11750185610079725, w_grad=[-1.17501856 -1.76252784 -0.11750186], b_grad=-0.11750185610079725
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0. 0. 0.], b_before=0
# [DEBUG] w_after=[0.11750186 0.17625278 0.01175019], b_after=0.011750185610079726
# [DEBUG] input=[ 5 10  0], weighted_sum=2.3617873076260247, predicted=0.9138665965300853
# [DEBUG] epoch=1, sample=2, actual=0, predicted=0.9138665965300853, error=0.9138665965300853
# [DEBUG] delta=0.18669702494825818, w_grad=[0.93348512 1.86697025 0.        ], b_grad=0.18669702494825818
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.11750186 0.17625278 0.01175019], b_before=0.011750185610079726
# [DEBUG] w_after=[ 0.02415334 -0.01044424  0.01175019], b_after=-0.006919516884746093
# [DEBUG] input=[ 8 12  1], weighted_sum=0.07272652817393085, predicted=0.5181736225014092
# [DEBUG] epoch=1, sample=3, actual=1, predicted=0.5181736225014092, error=-0.4818263774985908
# [DEBUG] delta=-0.11271937329102251, w_grad=[-0.90175499 -1.35263248 -0.11271937], b_grad=-0.11271937329102251
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.02415334 -0.01044424  0.01175019], b_before=-0.006919516884746093
# [DEBUG] w_after=[0.11432884 0.12481901 0.02302212], b_after=0.004352420444356159
# [DEBUG] input=[3 5 0], weighted_sum=0.971433982983638, predicted=0.7254052287277823
# [DEBUG] epoch=1, sample=4, actual=0, predicted=0.7254052287277823, error=0.7254052287277823
# [DEBUG] delta=0.15944036265298628, w_grad=[0.47832109 0.79720181 0.        ], b_grad=0.15944036265298628
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.11432884 0.12481901 0.02302212], b_before=0.004352420444356159
# [DEBUG] w_after=[0.06649673 0.04509883 0.02302212], b_after=-0.01159161582094247
# [DEBUG] input=[ 7 14  1], weighted_sum=1.1082912029227734, predicted=0.7518104016088765
# [DEBUG] epoch=1, sample=5, actual=1, predicted=0.7518104016088765, error=-0.24818959839112353
# [DEBUG] delta=-0.05404415873134314, w_grad=[-0.37830911 -0.75661822 -0.05404416], b_grad=-0.05404415873134314
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.06649673 0.04509883 0.02302212], b_before=-0.01159161582094247
# [DEBUG] w_after=[0.10432764 0.12076065 0.02842654], b_after=-0.006187199947808156
# [DEBUG] input=[4 8 0], weighted_sum=1.3772085627507293, predicted=0.7985423090028848
# [DEBUG] epoch=1, sample=6, actual=0, predicted=0.7985423090028848, error=0.7985423090028848
# [DEBUG] delta=0.17091049758228105, w_grad=[0.68364199 1.36728398 0.        ], b_grad=0.17091049758228105
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.10432764 0.12076065 0.02842654], b_before=-0.006187199947808156
# [DEBUG] w_after=[ 0.03596345 -0.01596775  0.02842654], b_after=-0.02327824970603626
# [DEBUG] input=[ 9 13  1], weighted_sum=0.1212385487782949, predicted=0.5302725654460835
# [DEBUG] epoch=1, sample=7, actual=1, predicted=0.5302725654460835, error=-0.4697274345539165
# [DEBUG] delta=-0.10954873188798904, w_grad=[-0.98593859 -1.42413351 -0.10954873], b_grad=-0.10954873188798904
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.03596345 -0.01596775  0.02842654], b_before=-0.02327824970603626
# [DEBUG] w_after=[0.1345573  0.1264456  0.03938141], b_after=-0.012323376517237358
# [DEBUG] input=[2 4 0], weighted_sum=0.7625736377188306, predicted=0.6819122374092935
# [DEBUG] epoch=1, sample=8, actual=0, predicted=0.6819122374092935, error=0.6819122374092935
# [DEBUG] delta=0.15210034461919333, w_grad=[0.30420069 0.60840138 0.        ], b_grad=0.15210034461919333
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.1345573  0.1264456  0.03938141], b_before=-0.012323376517237358
# [DEBUG] w_after=[0.10413724 0.06560546 0.03938141], b_after=-0.02753341097915669
# [DEBUG] input=[6 9 0], weighted_sum=1.1877391732425804, predicted=0.7663364733427585
# [DEBUG] epoch=1, sample=9, actual=0, predicted=0.7663364733427585, error=0.7663364733427585
# [DEBUG] delta=0.16599654704349406, w_grad=[0.99597928 1.49396892 0.        ], b_grad=0.16599654704349406
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.10413724 0.06560546 0.03938141], b_before=-0.02753341097915669
# [DEBUG] w_after=[ 0.00453931 -0.08379143  0.03938141], b_after=-0.0441330656835061
# [DEBUG] input=[11 16  1], weighted_sum=-1.2954821356511328, predicted=0.21492634798948954
# [DEBUG] epoch=1, sample=10, actual=1, predicted=0.21492634798948954, error=-0.7850736520105105
# [DEBUG] delta=-0.1940191764459396, w_grad=[-2.13421094 -3.10430682 -0.19401918], b_grad=-0.1940191764459396
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.00453931 -0.08379143  0.03938141], b_before=-0.0441330656835061
# [DEBUG] w_after=[0.2179604  0.22663925 0.05878333], b_after=-0.024731148038912135
# epoch=1, loss=0.4432049847947397
# [DEBUG] input=[10 15  1], weighted_sum=5.613244996902778, predicted=0.9963640598498225
# [DEBUG] epoch=2, sample=1, actual=1, predicted=0.9963640598498225, error=-0.0036359401501775412
# [DEBUG] delta=-0.000716069514420495, w_grad=[-0.0071607  -0.01074104 -0.00071607], b_grad=-0.000716069514420495
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.2179604  0.22663925 0.05878333], b_before=-0.024731148038912135
# [DEBUG] w_after=[0.21867647 0.22771336 0.05885494], b_after=-0.024659541087470087
# [DEBUG] input=[ 5 10  0], weighted_sum=3.345856390760916, predicted=0.9659688856704546
# [DEBUG] epoch=2, sample=2, actual=0, predicted=0.9659688856704546, error=0.9659688856704546
# [DEBUG] delta=0.1928872308186819, w_grad=[0.96443615 1.92887231 0.        ], b_grad=0.1928872308186819
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.21867647 0.22771336 0.05885494], b_before=-0.024659541087470087
# [DEBUG] w_after=[0.12223286 0.03482613 0.05885494], b_after=-0.04394826416933828
# [DEBUG] input=[ 8 12  1], weighted_sum=1.4106830389406204, predicted=0.8038736544534895
# [DEBUG] epoch=2, sample=3, actual=1, predicted=0.8038736544534895, error=-0.19612634554651054
# [DEBUG] delta=-0.04189149154771505, w_grad=[-0.33513193 -0.5026979  -0.04189149], b_grad=-0.04189149154771505
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.12223286 0.03482613 0.05885494], b_before=-0.04394826416933828
# [DEBUG] w_after=[0.15574605 0.08509592 0.06304409], b_after=-0.039759115014566776
# [DEBUG] input=[3 5 0], weighted_sum=0.8529586149374141, predicted=0.701187410956354
# [DEBUG] epoch=2, sample=4, actual=0, predicted=0.701187410956354, error=0.701187410956354
# [DEBUG] delta=0.15540014530572868, w_grad=[0.46620044 0.77700073 0.        ], b_grad=0.15540014530572868
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.15574605 0.08509592 0.06304409], b_before=-0.039759115014566776
# [DEBUG] w_after=[0.109126   0.00739584 0.06304409], b_after=-0.055299129545139644
# [DEBUG] input=[ 7 14  1], weighted_sum=0.875168809854277, predicted=0.7058200804112855
# [DEBUG] epoch=2, sample=5, actual=1, predicted=0.7058200804112855, error=-0.2941799195887145
# [DEBUG] delta=-0.0650954214568151, w_grad=[-0.45566795 -0.9113359  -0.06509542], b_grad=-0.0650954214568151
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.109126   0.00739584 0.06304409], b_before=-0.055299129545139644
# [DEBUG] w_after=[0.1546928  0.09852943 0.06955363], b_after=-0.048789587399458136
# [DEBUG] input=[4 8 0], weighted_sum=1.3582170865088068, predicted=0.7954697747554811
# [DEBUG] epoch=2, sample=6, actual=0, predicted=0.7954697747554811, error=0.7954697747554811
# [DEBUG] delta=0.1704510880037502, w_grad=[0.68180435 1.3636087  0.        ], b_grad=0.1704510880037502
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.1546928  0.09852943 0.06955363], b_before=-0.048789587399458136
# [DEBUG] w_after=[ 0.08651236 -0.03783144  0.06955363], b_after=-0.06583469619983315
# [DEBUG] input=[ 9 13  1], weighted_sum=0.2905215446304744, predicted=0.5721238108950922
# [DEBUG] epoch=2, sample=7, actual=1, predicted=0.5721238108950922, error=-0.42787618910490777
# [DEBUG] delta=-0.09867191920512161, w_grad=[-0.88804727 -1.28273495 -0.09867192], b_grad=-0.09867191920512161
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.08651236 -0.03783144  0.06955363], b_before=-0.06583469619983315
# [DEBUG] w_after=[0.17531709 0.09044206 0.07942082], b_after=-0.055967504279320984
# [DEBUG] input=[2 4 0], weighted_sum=0.6564349150956621, predicted=0.6584590874686805
# [DEBUG] epoch=2, sample=8, actual=0, predicted=0.6584590874686805, error=0.6584590874686805
# [DEBUG] delta=0.14798623708622752, w_grad=[0.29597247 0.59194495 0.        ], b_grad=0.14798623708622752
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.17531709 0.09044206 0.07942082], b_before=-0.055967504279320984
# [DEBUG] w_after=[0.14571984 0.03124756 0.07942082], b_after=-0.07076612798794374
# [DEBUG] input=[6 9 0], weighted_sum=1.0847810156471054, predicted=0.7473976794431207
# [DEBUG] epoch=2, sample=9, actual=0, predicted=0.7473976794431207, error=0.7473976794431207
# [DEBUG] delta=0.1630059143888775, w_grad=[0.97803549 1.46705323 0.        ], b_grad=0.1630059143888775
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.14571984 0.03124756 0.07942082], b_before=-0.07076612798794374
# [DEBUG] w_after=[ 0.0479163  -0.11545776  0.07942082], b_after=-0.08706671942683149
# [DEBUG] input=[11 16  1], weighted_sum=-1.3278907871063086, predicted=0.20950846778226992
# [DEBUG] epoch=2, sample=10, actual=1, predicted=0.20950846778226992, error=-0.79049153221773
# [DEBUG] delta=-0.19547004494955808, w_grad=[-2.15017049 -3.12752072 -0.19547004], b_grad=-0.19547004494955808
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.0479163  -0.11545776  0.07942082], b_before=-0.08706671942683149
# [DEBUG] w_after=[0.26293335 0.19729431 0.09896782], b_after=-0.06751971493187568
# epoch=2, loss=0.39826789813019803
# [DEBUG] input=[10 15  1], weighted_sum=5.620196258091033, predicted=0.9963891556329322
# [DEBUG] epoch=3, sample=1, actual=1, predicted=0.9963891556329322, error=-0.0036108443670678225
# [DEBUG] delta=-0.0007111188778150871, w_grad=[-0.00711119 -0.01066678 -0.00071112], b_grad=-0.0007111188778150871
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.26293335 0.19729431 0.09896782], b_before=-0.06751971493187568
# [DEBUG] w_after=[0.26364446 0.19836099 0.09903894], b_after=-0.06744860304409417
# [DEBUG] input=[ 5 10  0], weighted_sum=3.2343836312674963, predicted=0.9621078880357233
# [DEBUG] epoch=3, sample=2, actual=0, predicted=0.9621078880357233, error=0.9621078880357233
# [DEBUG] delta=0.19244874813480123, w_grad=[0.96224374 1.92448748 0.        ], b_grad=0.19244874813480123
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.26364446 0.19836099 0.09903894], b_before=-0.06744860304409417
# [DEBUG] w_after=[0.16742009 0.00591224 0.09903894], b_after=-0.0866934778575743
# [DEBUG] input=[ 8 12  1], weighted_sum=1.4226530979775214, predicted=0.8057540015636556
# [DEBUG] epoch=3, sample=3, actual=1, predicted=0.8057540015636556, error=-0.19424599843634438
# [DEBUG] delta=-0.04146006824609143, w_grad=[-0.33168055 -0.49752082 -0.04146007], b_grad=-0.04146006824609143
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.16742009 0.00591224 0.09903894], b_before=-0.0866934778575743
# [DEBUG] w_after=[0.20058814 0.05566433 0.10318494], b_after=-0.08254747103296516
# [DEBUG] input=[3 5 0], weighted_sum=0.7975385886680785, predicted=0.6894477153240394
# [DEBUG] epoch=3, sample=4, actual=0, predicted=0.6894477153240394, error=0.6894477153240394
# [DEBUG] delta=0.1533991856465982, w_grad=[0.46019756 0.76699593 0.        ], b_grad=0.1533991856465982
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.20058814 0.05566433 0.10318494], b_before=-0.08254747103296516
# [DEBUG] w_after=[ 0.15456839 -0.02103527  0.10318494], b_after=-0.09788738959762498
# [DEBUG] input=[ 7 14  1], weighted_sum=0.7927825284334472, predicted=0.6884284809106845
# [DEBUG] epoch=3, sample=5, actual=1, predicted=0.6884284809106845, error=-0.31157151908931546
# [DEBUG] delta=-0.06934676235941527, w_grad=[-0.48542734 -0.97085467 -0.06934676], b_grad=-0.06934676235941527
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.15456839 -0.02103527  0.10318494], b_before=-0.09788738959762498
# [DEBUG] w_after=[0.20311112 0.0760502  0.11011962], b_after=-0.09095271336168345
# [DEBUG] input=[4 8 0], weighted_sum=1.32989337395905, predicted=0.7908229970426058
# [DEBUG] epoch=3, sample=6, actual=0, predicted=0.7908229970426058, error=0.7908229970426058
# [DEBUG] delta=0.16975251744582942, w_grad=[0.67901007 1.35802014 0.        ], b_grad=0.16975251744582942
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.20311112 0.0760502  0.11011962], b_before=-0.09095271336168345
# [DEBUG] w_after=[ 0.13521012 -0.05975181  0.11011962], b_after=-0.1079279651062664
# [DEBUG] input=[ 9 13  1], weighted_sum=0.44230910879886803, predicted=0.6088091073965374
# [DEBUG] epoch=3, sample=7, actual=1, predicted=0.6088091073965374, error=-0.3911908926034626
# [DEBUG] delta=-0.08926735126077871, w_grad=[-0.80340616 -1.16047557 -0.08926735], b_grad=-0.08926735126077871
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.13521012 -0.05975181  0.11011962], b_before=-0.1079279651062664
# [DEBUG] w_after=[0.21555073 0.05629574 0.11904635], b_after=-0.09900122998018852
# [DEBUG] input=[2 4 0], weighted_sum=0.5572832027223114, predicted=0.6358236930785482
# [DEBUG] epoch=3, sample=8, actual=0, predicted=0.6358236930785482, error=0.6358236930785482
# [DEBUG] delta=0.14391415037512736, w_grad=[0.2878283 0.5756566 0.       ], b_grad=0.14391415037512736
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.21555073 0.05629574 0.11904635], b_before=-0.09900122998018852
# [DEBUG] w_after=[ 0.1867679  -0.00126992  0.11904635], b_after=-0.11339264501770126
# [DEBUG] input=[6 9 0], weighted_sum=0.995785504690356, predicted=0.7302291520955683
# [DEBUG] epoch=3, sample=9, actual=0, predicted=0.7302291520955683, error=0.7302291520955683
# [DEBUG] delta=0.16023092192556604, w_grad=[0.96138553 1.4420783  0.        ], b_grad=0.16023092192556604
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.1867679  -0.00126992  0.11904635], b_before=-0.11339264501770126
# [DEBUG] w_after=[ 0.09062935 -0.14547775  0.11904635], b_after=-0.12941573721025787
# [DEBUG] input=[11 16  1], weighted_sum=-1.3410905098196704, predicted=0.20733078181918801
# [DEBUG] epoch=3, sample=10, actual=1, predicted=0.20733078181918801, error=-0.7926692181808119
# [DEBUG] delta=-0.19605286181967957, w_grad=[-2.15658148 -3.13684579 -0.19605286], b_grad=-0.19605286181967957
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.09062935 -0.14547775  0.11904635], b_before=-0.12941573721025787
# [DEBUG] w_after=[0.3062875  0.16820683 0.13865164], b_after=-0.10981045102828992
# epoch=3, loss=0.38800732978082764
# [DEBUG] input=[10 15  1], weighted_sum=5.614818625194837, predicted=0.9963697562140863
# [DEBUG] epoch=4, sample=1, actual=1, predicted=0.9963697562140863, error=-0.0036302437859137004
# [DEBUG] delta=-0.0007149457845591106, w_grad=[-0.00714946 -0.01072419 -0.00071495], b_grad=-0.0007149457845591106
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.3062875  0.16820683 0.13865164], b_before=-0.10981045102828992
# [DEBUG] w_after=[0.30700244 0.16927925 0.13872314], b_after=-0.109738956449834
# [DEBUG] input=[ 5 10  0], weighted_sum=3.1180657551382787, predicted=0.9576318192427405
# [DEBUG] epoch=4, sample=2, actual=0, predicted=0.9576318192427405, error=0.9576318192427405
# [DEBUG] delta=0.19193635749147844, w_grad=[0.95968179 1.91936357 0.        ], b_grad=0.19193635749147844
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.30700244 0.16927925 0.13872314], b_before=-0.109738956449834
# [DEBUG] w_after=[ 0.21103426 -0.02265711  0.13872314], b_after=-0.12893259219898184
# [DEBUG] input=[ 8 12  1], weighted_sum=1.4261793620067467, predicted=0.8063053179979014
# [DEBUG] epoch=4, sample=3, actual=1, predicted=0.8063053179979014, error=-0.1936946820020986
# [DEBUG] delta=-0.04133367680407036, w_grad=[-0.33066941 -0.49600412 -0.04133368], b_grad=-0.04133367680407036
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.21103426 -0.02265711  0.13872314], b_before=-0.12893259219898184
# [DEBUG] w_after=[0.24410121 0.0269433  0.1428565 ], b_after=-0.12479922451857481
# [DEBUG] input=[3 5 0], weighted_sum=0.7422209139889983, predicted=0.677481317948277
# [DEBUG] epoch=4, sample=4, actual=0, predicted=0.677481317948277, error=0.677481317948277
# [DEBUG] delta=0.15133136499512828, w_grad=[0.45399409 0.75665682 0.        ], b_grad=0.15133136499512828
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.24410121 0.0269433  0.1428565 ], b_before=-0.12479922451857481
# [DEBUG] w_after=[ 0.1987018  -0.04872238  0.1428565 ], b_after=-0.13993236101808765
# [DEBUG] input=[ 7 14  1], weighted_sum=0.7117234208882197, predicted=0.6707818609292211
# [DEBUG] epoch=4, sample=5, actual=1, predicted=0.6707818609292211, error=-0.3292181390707789
# [DEBUG] delta=-0.07369882423010116, w_grad=[-0.51589177 -1.03178354 -0.07369882], b_grad=-0.07369882423010116
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.1987018  -0.04872238  0.1428565 ], b_before=-0.13993236101808765
# [DEBUG] w_after=[0.25029097 0.05445598 0.15022639], b_after=-0.13256247859507753
# [DEBUG] input=[4 8 0], weighted_sum=1.3042492200994786, predicted=0.7865492512195336
# [DEBUG] epoch=4, sample=6, actual=0, predicted=0.7865492512195336, error=0.7865492512195336
# [DEBUG] delta=0.16910601747273674, w_grad=[0.67642407 1.35284814 0.        ], b_grad=0.16910601747273674
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.25029097 0.05445598 0.15022639], b_before=-0.13256247859507753
# [DEBUG] w_after=[ 0.18264857 -0.08082884  0.15022639], b_after=-0.1494730803423512
# [DEBUG] input=[ 9 13  1], weighted_sum=0.5938155023391116, predicted=0.6442401194229302
# [DEBUG] epoch=4, sample=7, actual=1, predicted=0.6442401194229302, error=-0.35575988057706975
# [DEBUG] delta=-0.08031421118572199, w_grad=[-0.7228279  -1.04408475 -0.08031421], b_grad=-0.08031421118572199
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.18264857 -0.08082884  0.15022639], b_before=-0.1494730803423512
# [DEBUG] w_after=[0.25493136 0.02357964 0.15825781], b_after=-0.14144165922377902
# [DEBUG] input=[2 4 0], weighted_sum=0.46273959853260593, predicted=0.6136638834966177
# [DEBUG] epoch=4, sample=8, actual=0, predicted=0.6136638834966177, error=0.6136638834966177
# [DEBUG] delta=0.13983292780962217, w_grad=[0.27966586 0.55933171 0.        ], b_grad=0.13983292780962217
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.25493136 0.02357964 0.15825781], b_before=-0.14144165922377902
# [DEBUG] w_after=[ 0.22696477 -0.03235353  0.15825781], b_after=-0.15542495200474124
# [DEBUG] input=[6 9 0], weighted_sum=0.9151818580799016, predicted=0.7140593597491534
# [DEBUG] epoch=4, sample=9, actual=0, predicted=0.7140593597491534, error=0.7140593597491534
# [DEBUG] delta=0.15756231290973888, w_grad=[0.94537388 1.41806082 0.        ], b_grad=0.15756231290973888
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.22696477 -0.03235353  0.15825781], b_before=-0.15542495200474124
# [DEBUG] w_after=[ 0.13242738 -0.17415962  0.15825781], b_after=-0.17118118329571513
# [DEBUG] input=[11 16  1], weighted_sum=-1.342776028929621, predicted=0.20705391228346337
# [DEBUG] epoch=4, sample=10, actual=1, predicted=0.20705391228346337, error=-0.7929460877165366
# [DEBUG] delta=-0.19612694597204208, w_grad=[-2.15739641 -3.13803114 -0.19612695], b_grad=-0.19612694597204208
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.13242738 -0.17415962  0.15825781], b_before=-0.17118118329571513
# [DEBUG] w_after=[0.34816702 0.1396435  0.1778705 ], b_after=-0.15156848869851092
# epoch=4, loss=0.3782407475394864
# [DEBUG] input=[10 15  1], weighted_sum=5.602624703024558, predicted=0.9963253819696859
# [DEBUG] epoch=5, sample=1, actual=1, predicted=0.9963253819696859, error=-0.003674618030314103
# [DEBUG] delta=-0.0007236997103231933, w_grad=[-0.007237  -0.0108555 -0.0007237], b_grad=-0.0007236997103231933
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.34816702 0.1396435  0.1778705 ], b_before=-0.15156848869851092
# [DEBUG] w_after=[0.34889072 0.14072905 0.17794287], b_after=-0.1514961187274786
# [DEBUG] input=[ 5 10  0], weighted_sum=3.0002479643038757, predicted=0.9525853277643628
# [DEBUG] epoch=5, sample=2, actual=0, predicted=0.9525853277643628, error=0.9525853277643628
# [DEBUG] delta=0.19135344553157058, w_grad=[0.95676723 1.91353446 0.        ], b_grad=0.19135344553157058
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.34889072 0.14072905 0.17794287], b_before=-0.1514961187274786
# [DEBUG] w_after=[ 0.253214   -0.0506244   0.17794287], b_after=-0.17063146328063566
# [DEBUG] input=[ 8 12  1], weighted_sum=1.425530624225546, predicted=0.8062039799100816
# [DEBUG] epoch=5, sample=3, actual=1, predicted=0.8062039799100816, error=-0.19379602008991836
# [DEBUG] delta=-0.04135690549759787, w_grad=[-0.33085524 -0.49628287 -0.04135691], b_grad=-0.04135690549759787
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.253214   -0.0506244   0.17794287], b_before=-0.17063146328063566
# [DEBUG] w_after=[ 0.28629952 -0.00099611  0.18207856], b_after=-0.16649577273087587
# [DEBUG] input=[3 5 0], weighted_sum=0.6874222403683029, predicted=0.6653932461705155
# [DEBUG] epoch=5, sample=4, actual=0, predicted=0.6653932461705155, error=0.6653932461705155
# [DEBUG] delta=0.14921383785694123, w_grad=[0.44764151 0.74606919 0.        ], b_grad=0.14921383785694123
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.28629952 -0.00099611  0.18207856], b_before=-0.16649577273087587
# [DEBUG] w_after=[ 0.24153537 -0.07560303  0.18207856], b_after=-0.18141715651657
# [DEBUG] input=[ 7 14  1], weighted_sum=0.6329665830607591, predicted=0.6531618212450411
# [DEBUG] epoch=5, sample=5, actual=1, predicted=0.6531618212450411, error=-0.3468381787549589
# [DEBUG] delta=-0.07808145104481114, w_grad=[-0.54657016 -1.09314031 -0.07808145], b_grad=-0.07808145104481114
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.24153537 -0.07560303  0.18207856], b_before=-0.18141715651657
# [DEBUG] w_after=[0.29619239 0.033711   0.18988671], b_after=-0.1736090114120889
# [DEBUG] input=[4 8 0], weighted_sum=1.2808485478378027, predicted=0.7825941834192084
# [DEBUG] epoch=5, sample=6, actual=0, predicted=0.7825941834192084, error=0.7825941834192084
# [DEBUG] delta=0.16850430836864058, w_grad=[0.67401723 1.34803447 0.        ], b_grad=0.16850430836864058
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.29619239 0.033711   0.18988671], b_before=-0.1736090114120889
# [DEBUG] w_after=[ 0.22879067 -0.10109245  0.18988671], b_after=-0.19045944224895295
# [DEBUG] input=[ 9 13  1], weighted_sum=0.7443414527744142, predicted=0.6779444819943337
# [DEBUG] epoch=5, sample=7, actual=1, predicted=0.6779444819943337, error=-0.32205551800566634
# [DEBUG] delta=-0.07192778786296616, w_grad=[-0.64735009 -0.93506124 -0.07192779], b_grad=-0.07192778786296616
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.22879067 -0.10109245  0.18988671], b_before=-0.19045944224895295
# [DEBUG] w_after=[ 0.29352567 -0.00758632  0.19707949], b_after=-0.18326666346265633
# [DEBUG] input=[2 4 0], weighted_sum=0.3734393977284902, predicted=0.59228979601671
# [DEBUG] epoch=5, sample=8, actual=0, predicted=0.59228979601671, error=0.59228979601671
# [DEBUG] delta=0.1358094232478362, w_grad=[0.27161885 0.54323769 0.        ], b_grad=0.1358094232478362
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.29352567 -0.00758632  0.19707949], b_before=-0.18326666346265633
# [DEBUG] w_after=[ 0.26636379 -0.06191009  0.19707949], b_after=-0.19684760578743996
# [DEBUG] input=[6 9 0], weighted_sum=0.8441443119833789, predicted=0.6993373374366773
# [DEBUG] epoch=5, sample=9, actual=0, predicted=0.6993373374366773, error=0.6993373374366773
# [DEBUG] delta=0.1550866408869089, w_grad=[0.93051985 1.39577977 0.        ], b_grad=0.1550866408869089
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.26636379 -0.06191009  0.19707949], b_before=-0.19684760578743996
# [DEBUG] w_after=[ 0.17331181 -0.20148807  0.19707949], b_after=-0.21235626987613085
# [DEBUG] input=[11 16  1], weighted_sum=-1.332656014928647, predicted=0.20872036857458187
# [DEBUG] epoch=5, sample=10, actual=1, predicted=0.20872036857458187, error=-0.7912796314254181
# [DEBUG] delta=-0.19568098866425326, w_grad=[-2.15249088 -3.13089582 -0.19568099], b_grad=-0.19568098866425326
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.17331181 -0.20148807  0.19707949], b_before=-0.21235626987613085
# [DEBUG] w_after=[0.38856089 0.11160151 0.21664758], b_after=-0.19278817100970552
# epoch=5, loss=0.36902108828904506
# [DEBUG] input=[10 15  1], weighted_sum=5.583491048807562, predicted=0.9962546620213949
# [DEBUG] epoch=6, sample=1, actual=1, predicted=0.9962546620213949, error=-0.003745337978605101
# [DEBUG] delta=-0.0007376517207933215, w_grad=[-0.00737652 -0.01106478 -0.00073765], b_grad=-0.0007376517207933215
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.38856089 0.11160151 0.21664758], b_before=-0.19278817100970552
# [DEBUG] w_after=[0.38929854 0.11270799 0.21672135], b_after=-0.1927144058376262
# [DEBUG] input=[ 5 10  0], weighted_sum=2.880858230955464, predicted=0.9468920384527154
# [DEBUG] epoch=6, sample=2, actual=0, predicted=0.9468920384527154, error=0.9468920384527154
# [DEBUG] delta=0.19068917771912527, w_grad=[0.95344589 1.90689178 0.        ], b_grad=0.19068917771912527
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.38929854 0.11270799 0.21672135], b_before=-0.1927144058376262
# [DEBUG] w_after=[ 0.29395396 -0.07798119  0.21672135], b_after=-0.21178332360953872
# [DEBUG] input=[ 8 12  1], weighted_sum=1.4207954354999952, predicted=0.8054630853142116
# [DEBUG] epoch=6, sample=3, actual=1, predicted=0.8054630853142116, error=-0.19453691468578838
# [DEBUG] delta=-0.041526780506042964, w_grad=[-0.33221424 -0.49832137 -0.04152678], b_grad=-0.041526780506042964
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.29395396 -0.07798119  0.21672135], b_before=-0.21178332360953872
# [DEBUG] w_after=[ 0.32717538 -0.02814905  0.22087403], b_after=-0.20763064555893443
# [DEBUG] input=[3 5 0], weighted_sum=0.6331502461757212, predicted=0.6532034273841072
# [DEBUG] epoch=6, sample=4, actual=0, predicted=0.6532034273841072, error=0.6532034273841072
# [DEBUG] delta=0.14704956131850483, w_grad=[0.44114868 0.73524781 0.        ], b_grad=0.14704956131850483
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.32717538 -0.02814905  0.22087403], b_before=-0.20763064555893443
# [DEBUG] w_after=[ 0.28306051 -0.10167383  0.22087403], b_after=-0.22233560169078492
# [DEBUG] input=[ 7 14  1], weighted_sum=0.5565283825395955, predicted=0.6356488951002452
# [DEBUG] epoch=6, sample=5, actual=1, predicted=0.6356488951002452, error=-0.36435110489975475
# [DEBUG] delta=-0.08247270348322389, w_grad=[-0.57730892 -1.15461785 -0.0824727 ], b_grad=-0.08247270348322389
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.28306051 -0.10167383  0.22087403], b_before=-0.22233560169078492
# [DEBUG] w_after=[0.3407914  0.01378795 0.2291213 ], b_after=-0.21408833134246252
# [DEBUG] input=[4 8 0], weighted_sum=1.2593809212870157, predicted=0.778919518418163
# [DEBUG] epoch=6, sample=6, actual=0, predicted=0.778919518418163, error=0.778919518418163
# [DEBUG] delta=0.16794232054465388, w_grad=[0.67176928 1.34353856 0.        ], b_grad=0.16794232054465388
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.3407914  0.01378795 0.2291213 ], b_before=-0.21408833134246252
# [DEBUG] w_after=[ 0.27361448 -0.1205659   0.2291213 ], b_after=-0.23088256339692792
# [DEBUG] input=[ 9 13  1], weighted_sum=0.8934122925951841, predicted=0.7095938477135014
# [DEBUG] epoch=6, sample=7, actual=1, predicted=0.7095938477135014, error=-0.2904061522864986
# [DEBUG] delta=-0.06417802419857216, w_grad=[-0.57760222 -0.83431431 -0.06417802], b_grad=-0.06417802419857216
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.27361448 -0.1205659   0.2291213 ], b_before=-0.23088256339692792
# [DEBUG] w_after=[ 0.3313747  -0.03713447  0.2355391 ], b_after=-0.22446476097707072
# [DEBUG] input=[2 4 0], weighted_sum=0.289746752549058, predicted=0.5719341326324399
# [DEBUG] epoch=6, sample=8, actual=0, predicted=0.5719341326324399, error=0.5719341326324399
# [DEBUG] delta=0.1318998831421725, w_grad=[0.26379977 0.52759953 0.        ], b_grad=0.1318998831421725
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.3313747  -0.03713447  0.2355391 ], b_before=-0.22446476097707072
# [DEBUG] w_after=[ 0.30499472 -0.08989442  0.2355391 ], b_after=-0.23765474929128796
# [DEBUG] input=[6 9 0], weighted_sum=0.7832637635683117, predicted=0.6863831030653499
# [DEBUG] epoch=6, sample=9, actual=0, predicted=0.6863831030653499, error=0.6863831030653499
# [DEBUG] delta=0.15287231828020098, w_grad=[0.91723391 1.37585086 0.        ], b_grad=0.15287231828020098
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.30499472 -0.08989442  0.2355391 ], b_before=-0.23765474929128796
# [DEBUG] w_after=[ 0.21327133 -0.22747951  0.2355391 ], b_after=-0.25294198111930805
# [DEBUG] input=[11 16  1], weighted_sum=-1.3110904126692637, predicted=0.21230443583070385
# [DEBUG] epoch=6, sample=10, actual=1, predicted=0.21230443583070385, error=-0.7876955641692962
# [DEBUG] delta=-0.19472145858043977, w_grad=[-2.14193604 -3.11554334 -0.19472146], b_grad=-0.19472145858043977
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.21327133 -0.22747951  0.2355391 ], b_before=-0.25294198111930805
# [DEBUG] w_after=[0.42746493 0.08407482 0.25501125], b_after=-0.23346983526126408
# epoch=6, loss=0.3603635683919453
# [DEBUG] input=[10 15  1], weighted_sum=5.5573131094502095, predicted=0.9961557040996889
# [DEBUG] epoch=7, sample=1, actual=1, predicted=0.9961557040996889, error=-0.003844295900311101
# [DEBUG] delta=-0.0007571761922389334, w_grad=[-0.00757176 -0.01135764 -0.00075718], b_grad=-0.0007571761922389334
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.42746493 0.08407482 0.25501125], b_before=-0.23346983526126408
# [DEBUG] w_after=[0.42822211 0.08521059 0.25508696], b_after=-0.23339411764204018
# [DEBUG] input=[ 5 10  0], weighted_sum=2.7598223144242415, predicted=0.9404656861903793
# [DEBUG] epoch=7, sample=2, actual=0, predicted=0.9404656861903793, error=0.9404656861903793
# [DEBUG] delta=0.18993091593460207, w_grad=[0.94965458 1.89930916 0.        ], b_grad=0.18993091593460207
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.42822211 0.08521059 0.25508696], b_before=-0.23339411764204018
# [DEBUG] w_after=[ 0.33325665 -0.10472033  0.25508696], b_after=-0.2523872092355004
# [DEBUG] input=[ 8 12  1], weighted_sum=1.4121090394162825, predicted=0.8040983814146571
# [DEBUG] epoch=7, sample=3, actual=1, predicted=0.8040983814146571, error=-0.19590161858534294
# [DEBUG] delta=-0.04183990245791872, w_grad=[-0.33471922 -0.50207883 -0.0418399 ], b_grad=-0.04183990245791872
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.33325665 -0.10472033  0.25508696], b_before=-0.2523872092355004
# [DEBUG] w_after=[ 0.36672857 -0.05451245  0.25927095], b_after=-0.2482032189897085
# [DEBUG] input=[3 5 0], weighted_sum=0.5794202794681991, predicted=0.6409340017420138
# [DEBUG] epoch=7, sample=4, actual=0, predicted=0.6409340017420138, error=0.6409340017420138
# [DEBUG] delta=0.14484210130961042, w_grad=[0.4345263  0.72421051 0.        ], b_grad=0.14484210130961042
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.36672857 -0.05451245  0.25927095], b_before=-0.2482032189897085
# [DEBUG] w_after=[ 0.32327594 -0.1269335   0.25927095], b_after=-0.26268742912066956
# [DEBUG] input=[ 7 14  1], weighted_sum=0.4824461940155301, predicted=0.6183253412464875
# [DEBUG] epoch=7, sample=5, actual=1, predicted=0.6183253412464875, error=-0.3816746587535125
# [DEBUG] delta=-0.08684957252469973, w_grad=[-0.60794701 -1.21589402 -0.08684957], b_grad=-0.08684957252469973
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.32327594 -0.1269335   0.25927095], b_before=-0.26268742912066956
# [DEBUG] w_after=[ 0.38407065 -0.00534409  0.26795591], b_after=-0.2540024718681996
# [DEBUG] input=[4 8 0], weighted_sum=1.2395273544359866, predicted=0.7754817327524152
# [DEBUG] epoch=7, sample=6, actual=0, predicted=0.7754817327524152, error=0.7754817327524152
# [DEBUG] delta=0.1674140017281334, w_grad=[0.66965601 1.33931201 0.        ], b_grad=0.1674140017281334
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.38407065 -0.00534409  0.26795591], b_before=-0.2540024718681996
# [DEBUG] w_after=[ 0.31710504 -0.1392753   0.26795591], b_after=-0.2707438720410129
# [DEBUG] input=[ 9 13  1], weighted_sum=1.0405785954203268, predicted=0.7389616310315128
# [DEBUG] epoch=7, sample=7, actual=1, predicted=0.7389616310315128, error=-0.2610383689684872
# [DEBUG] delta=-0.05710287630713967, w_grad=[-0.51392589 -0.74233739 -0.05710288], b_grad=-0.05710287630713967
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.31710504 -0.1392753   0.26795591], b_before=-0.2707438720410129
# [DEBUG] w_after=[ 0.36849763 -0.06504156  0.2736662 ], b_after=-0.26503358441029895
# [DEBUG] input=[2 4 0], weighted_sum=0.21179545597923827, predicted=0.5527518191810723
# [DEBUG] epoch=7, sample=8, actual=0, predicted=0.5527518191810723, error=0.5527518191810723
# [DEBUG] delta=0.1281477836533863, w_grad=[0.25629557 0.51259113 0.        ], b_grad=0.1281477836533863
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.36849763 -0.06504156  0.2736662 ], b_before=-0.26503358441029895
# [DEBUG] w_after=[ 0.34286808 -0.11630067  0.2736662 ], b_after=-0.27784836277563757
# [DEBUG] input=[6 9 0], weighted_sum=0.7326540661619756, predicted=0.6753874187073988
# [DEBUG] epoch=7, sample=9, actual=0, predicted=0.6753874187073988, error=0.6753874187073988
# [DEBUG] delta=0.1509666233692068, w_grad=[0.90579974 1.35869961 0.        ], b_grad=0.1509666233692068
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.34286808 -0.11630067  0.2736662 ], b_before=-0.27784836277563757
# [DEBUG] w_after=[ 0.2522881  -0.25217063  0.2736662 ], b_after=-0.29294502511255827
# [DEBUG] input=[11 16  1], weighted_sum=-1.278839795689855, predicted=0.21774778073581197
# [DEBUG] epoch=7, sample=10, actual=1, predicted=0.21774778073581197, error=-0.7822522192641881
# [DEBUG] delta=-0.19326313968730643, w_grad=[-2.12589454 -3.09221023 -0.19326314], b_grad=-0.19326313968730643
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.2522881  -0.25217063  0.2736662 ], b_before=-0.29294502511255827
# [DEBUG] w_after=[0.46487756 0.05705039 0.29299251], b_after=-0.27361871114382763
# epoch=7, loss=0.35224540908069013
# [DEBUG] input=[10 15  1], weighted_sum=5.52390524991932, predicted=0.9960256240807923
# [DEBUG] epoch=8, sample=1, actual=1, predicted=0.9960256240807923, error=-0.003974375919207684
# [DEBUG] delta=-0.0007828437773820713, w_grad=[-0.00782844 -0.01174266 -0.00078284], b_grad=-0.0007828437773820713
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.46487756 0.05705039 0.29299251], b_before=-0.27361871114382763
# [DEBUG] w_after=[0.4656604  0.05822466 0.2930708 ], b_after=-0.2735404267660894
# [DEBUG] input=[ 5 10  0], weighted_sum=2.6370081543350707, predicted=0.933205715817048
# [DEBUG] epoch=8, sample=2, actual=0, predicted=0.933205715817048, error=0.933205715817048
# [DEBUG] delta=0.18906349885136117, w_grad=[0.94531749 1.89063499 0.        ], b_grad=0.18906349885136117
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.4656604  0.05822466 0.2930708 ], b_before=-0.2735404267660894
# [DEBUG] w_after=[ 0.37112865 -0.13083884  0.2930708 ], b_after=-0.29244677665122554
# [DEBUG] input=[ 8 12  1], weighted_sum=1.3995871357293719, predicted=0.8021183650602757
# [DEBUG] epoch=8, sample=3, actual=1, predicted=0.8021183650602757, error=-0.19788163493972433
# [DEBUG] delta=-0.04229470438818638, w_grad=[-0.33835764 -0.50753645 -0.0422947 ], b_grad=-0.04229470438818638
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.37112865 -0.13083884  0.2930708 ], b_before=-0.29244677665122554
# [DEBUG] w_after=[ 0.40496441 -0.0800852   0.29730027], b_after=-0.2882173062124069
# [DEBUG] input=[3 5 0], weighted_sum=0.5262499585381695, predicted=0.6286080504576084
# [DEBUG] epoch=8, sample=4, actual=0, predicted=0.6286080504576084, error=0.6286080504576084
# [DEBUG] delta=0.14259542539779835, w_grad=[0.42778628 0.71297713 0.        ], b_grad=0.14259542539779835
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.40496441 -0.0800852   0.29730027], b_before=-0.2882173062124069
# [DEBUG] w_after=[ 0.36218579 -0.15138291  0.29730027], b_after=-0.3024768487521867
# [DEBUG] input=[ 7 14  1], weighted_sum=0.41076320969351543, predicted=0.6012708680889024
# [DEBUG] epoch=8, sample=5, actual=1, predicted=0.6012708680889024, error=-0.3987291319110976
# [DEBUG] delta=-0.09118914160328047, w_grad=[-0.63832399 -1.27664798 -0.09118914], b_grad=-0.09118914160328047
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.36218579 -0.15138291  0.29730027], b_before=-0.3024768487521867
# [DEBUG] w_after=[ 0.42601819 -0.02371811  0.30641918], b_after=-0.29335793459185866
# [DEBUG] input=[4 8 0], weighted_sum=1.2209699283216182, predicted=0.7722341937516732
# [DEBUG] epoch=8, sample=6, actual=0, predicted=0.7722341937516732, error=0.7722341937516732
# [DEBUG] delta=0.16691265184841111, w_grad=[0.66765061 1.33530121 0.        ], b_grad=0.16691265184841111
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.42601819 -0.02371811  0.30641918], b_before=-0.29335793459185866
# [DEBUG] w_after=[ 0.35925312 -0.15724823  0.30641918], b_after=-0.31004919977669976
# [DEBUG] input=[ 9 13  1], weighted_sum=1.1854210967027177, predicted=0.7659211309969071
# [DEBUG] epoch=8, sample=7, actual=1, predicted=0.7659211309969071, error=-0.23407886900309294
# [DEBUG] delta=-0.05071164208344528, w_grad=[-0.45640478 -0.65925135 -0.05071164], b_grad=-0.05071164208344528
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.35925312 -0.15724823  0.30641918], b_before=-0.31004919977669976
# [DEBUG] w_after=[ 0.4048936  -0.0913231   0.31149035], b_after=-0.30497803556835523
# [DEBUG] input=[2 4 0], weighted_sum=0.1395167830788558, predicted=0.5348227289128246
# [DEBUG] epoch=8, sample=8, actual=0, predicted=0.5348227289128246, error=0.5348227289128246
# [DEBUG] delta=0.12458254281288755, w_grad=[0.24916509 0.49833017 0.        ], b_grad=0.12458254281288755
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.4048936  -0.0913231   0.31149035], b_before=-0.30497803556835523
# [DEBUG] w_after=[ 0.37997709 -0.14115611  0.31149035], b_after=-0.317436289849644
# [DEBUG] input=[6 9 0], weighted_sum=0.692021250309299, predicted=0.6664164130093779
# [DEBUG] epoch=8, sample=9, actual=0, predicted=0.6664164130093779, error=0.6664164130093779
# [DEBUG] delta=0.14939418136359336, w_grad=[0.89636509 1.34454763 0.        ], b_grad=0.14939418136359336
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.37997709 -0.14115611  0.31149035], b_before=-0.317436289849644
# [DEBUG] w_after=[ 0.29034059 -0.27561088  0.31149035], b_after=-0.33237570798600335
# [DEBUG] input=[11 16  1], weighted_sum=-1.2369129568181343, predicted=0.22497378734762963
# [DEBUG] epoch=8, sample=10, actual=1, predicted=0.22497378734762963, error=-0.7750262126523704
# [DEBUG] delta=-0.19132542687312454, w_grad=[-2.1045797  -3.06120683 -0.19132543], b_grad=-0.19132542687312454
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.29034059 -0.27561088  0.31149035], b_before=-0.33237570798600335
# [DEBUG] w_after=[0.50079855 0.03050981 0.33062289], b_after=-0.3132431652986909
# epoch=8, loss=0.3446129230980055
# [DEBUG] input=[10 15  1], weighted_sum=5.48301236095231, predicted=0.9958604182981151
# [DEBUG] epoch=9, sample=1, actual=1, predicted=0.9958604182981151, error=-0.004139581701884887
# [DEBUG] delta=-0.0008154468530174234, w_grad=[-0.00815447 -0.0122317  -0.00081545], b_grad=-0.0008154468530174234
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.50079855 0.03050981 0.33062289], b_before=-0.3132431652986909
# [DEBUG] w_after=[0.501614   0.03173298 0.33070443], b_after=-0.31316162061338915
# [DEBUG] input=[ 5 10  0], weighted_sum=2.512238150409607, predicted=0.9249953188870884
# [DEBUG] epoch=9, sample=2, actual=0, predicted=0.9249953188870884, error=0.9249953188870884
# [DEBUG] delta=0.188068731753117, w_grad=[0.94034366 1.88068732 0.        ], b_grad=0.188068731753117
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.501614   0.03173298 0.33070443], b_before=-0.31316162061338915
# [DEBUG] w_after=[ 0.40757964 -0.15633576  0.33070443], b_after=-0.33196849378870086
# [DEBUG] input=[ 8 12  1], weighted_sum=1.3833439597626778, predicted=0.799527517922058
# [DEBUG] epoch=9, sample=3, actual=1, predicted=0.799527517922058, error=-0.200472482077942
# [DEBUG] delta=-0.04289070476261913, w_grad=[-0.34312564 -0.51468846 -0.0428907 ], b_grad=-0.04289070476261913
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.40757964 -0.15633576  0.33070443], b_before=-0.33196849378870086
# [DEBUG] w_after=[ 0.4418922  -0.10486691  0.3349935 ], b_after=-0.32767942331243893
# [DEBUG] input=[3 5 0], weighted_sum=0.4736626265610191, predicted=0.6162502838080409
# [DEBUG] epoch=9, sample=4, actual=0, predicted=0.6162502838080409, error=0.6162502838080409
# [DEBUG] delta=0.14031403990138183, w_grad=[0.42094212 0.7015702  0.        ], b_grad=0.14031403990138183
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.4418922  -0.10486691  0.3349935 ], b_before=-0.32767942331243893
# [DEBUG] w_after=[ 0.39979799 -0.17502393  0.3349935 ], b_after=-0.3417108273025771
# [DEBUG] input=[ 7 14  1], weighted_sum=0.34153357387520117, predicted=0.5845629982006988
# [DEBUG] epoch=9, sample=5, actual=1, predicted=0.5845629982006988, error=-0.4154370017993012
# [DEBUG] delta=-0.09546860730184094, w_grad=[-0.66828025 -1.3365605  -0.09546861], b_grad=-0.09546860730184094
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.39979799 -0.17502393  0.3349935 ], b_before=-0.3417108273025771
# [DEBUG] w_after=[ 0.46662601 -0.04136788  0.34454036], b_after=-0.33216396657239305
# [DEBUG] input=[4 8 0], weighted_sum=1.203397048414946, predicted=0.7691285481968873
# [DEBUG] epoch=9, sample=6, actual=0, predicted=0.7691285481968873, error=0.7691285481968873
# [DEBUG] delta=0.16643114896824548, w_grad=[0.6657246  1.33144919 0.        ], b_grad=0.16643114896824548
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.46662601 -0.04136788  0.34454036], b_before=-0.33216396657239305
# [DEBUG] w_after=[ 0.40005355 -0.1745128   0.34454036], b_after=-0.34880708146921763
# [DEBUG] input=[ 9 13  1], weighted_sum=1.3275488783471197, predicted=0.7904349014874031
# [DEBUG] epoch=9, sample=7, actual=1, predicted=0.7904349014874031, error=-0.20956509851259686
# [DEBUG] delta=-0.04499033759972299, w_grad=[-0.40491304 -0.58487439 -0.04499034], b_grad=-0.04499033759972299
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.40005355 -0.1745128   0.34454036], b_before=-0.34880708146921763
# [DEBUG] w_after=[ 0.44054486 -0.11602536  0.3490394 ], b_after=-0.34430804770924534
# [DEBUG] input=[2 4 0], weighted_sum=0.07268022710950323, predicted=0.5181620625179183
# [DEBUG] epoch=9, sample=8, actual=0, predicted=0.5181620625179183, error=0.5181620625179183
# [DEBUG] delta=0.12122016725401324, w_grad=[0.24244033 0.48488067 0.        ], b_grad=0.12122016725401324
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.44054486 -0.11602536  0.3490394 ], b_before=-0.34430804770924534
# [DEBUG] w_after=[ 0.41630082 -0.16451343  0.3490394 ], b_after=-0.35643006443464664
# [DEBUG] input=[6 9 0], weighted_sum=0.6607540363322285, predicted=0.6594297519073705
# [DEBUG] epoch=9, sample=9, actual=0, predicted=0.6594297519073705, error=0.6594297519073705
# [DEBUG] delta=0.1481586442568739, w_grad=[0.88895187 1.3334278  0.        ], b_grad=0.1481586442568739
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.41630082 -0.16451343  0.3490394 ], b_before=-0.35643006443464664
# [DEBUG] w_after=[ 0.32740564 -0.29785621  0.3490394 ], b_after=-0.37124592886033403
# [DEBUG] input=[11 16  1], weighted_sum=-1.1864438285411023, predicted=0.23389555742221313
# [DEBUG] epoch=9, sample=10, actual=1, predicted=0.23389555742221313, error=-0.7661044425777869
# [DEBUG] delta=-0.18893034967345437, w_grad=[-2.07823385 -3.02288559 -0.18893035], b_grad=-0.18893034967345437
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.32740564 -0.29785621  0.3490394 ], b_before=-0.37124592886033403
# [DEBUG] w_after=[0.53522902 0.00443235 0.36793243], b_after=-0.3523528938929886
# epoch=9, loss=0.3373906798764574
# [DEBUG] input=[10 15  1], weighted_sum=5.434355049582872, predicted=0.9956549134605563
# [DEBUG] epoch=10, sample=1, actual=1, predicted=0.9956549134605563, error=-0.004345086539443654
# [DEBUG] delta=-0.000856009782344998, w_grad=[-0.0085601  -0.01284015 -0.00085601], b_grad=-0.000856009782344998
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.53522902 0.00443235 0.36793243], b_before=-0.3523528938929886
# [DEBUG] w_after=[0.53608503 0.00571637 0.36801803], b_after=-0.35226729291475406
# [DEBUG] input=[ 5 10  0], weighted_sum=2.385321540405734, predicted=0.9157011274275155
# [DEBUG] epoch=10, sample=2, actual=0, predicted=0.9157011274275155, error=0.9157011274275155
# [DEBUG] delta=0.18692499551344333, w_grad=[0.93462498 1.86924996 0.        ], b_grad=0.18692499551344333
# [DEBUG] lr=0.1
# [DEBUG] w_before=[0.53608503 0.00571637 0.36801803], b_before=-0.35226729291475406
# [DEBUG] w_after=[ 0.44262253 -0.18120863  0.36801803], b_after=-0.3709597924660984
# [DEBUG] input=[ 8 12  1], weighted_sum=1.3635349760792101, predicted=0.7963336233105763
# [DEBUG] epoch=10, sample=3, actual=1, predicted=0.7963336233105763, error=-0.20366637668942367
# [DEBUG] delta=-0.04362681891872025, w_grad=[-0.34901455 -0.52352183 -0.04362682], b_grad=-0.04362681891872025
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.44262253 -0.18120863  0.36801803], b_before=-0.3709597924660984
# [DEBUG] w_after=[ 0.47752399 -0.12885645  0.37238072], b_after=-0.3665971105742264
# [DEBUG] input=[3 5 0], weighted_sum=0.4216926297896467, predicted=0.60388821027794
# [DEBUG] epoch=10, sample=4, actual=0, predicted=0.60388821027794, error=0.60388821027794
# [DEBUG] delta=0.1380032251207687, w_grad=[0.41400968 0.69001613 0.        ], b_grad=0.1380032251207687
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.47752399 -0.12885645  0.37238072], b_before=-0.3665971105742264
# [DEBUG] w_after=[ 0.43612302 -0.19785806  0.37238072], b_after=-0.38039743308630325
# [DEBUG] input=[ 7 14  1], weighted_sum=0.2748316234301068, predicted=0.5682786747785475
# [DEBUG] epoch=10, sample=5, actual=1, predicted=0.5682786747785475, error=-0.43172132522145246
# [DEBUG] delta=-0.09966497451344739, w_grad=[-0.69765482 -1.39530964 -0.09966497], b_grad=-0.09966497451344739
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.43612302 -0.19785806  0.37238072], b_before=-0.38039743308630325
# [DEBUG] w_after=[ 0.5058885  -0.05832709  0.38234721], b_after=-0.3704309356349585
# [DEBUG] input=[4 8 0], weighted_sum=1.1865063306068846, predicted=0.7661156420382798
# [DEBUG] epoch=10, sample=6, actual=0, predicted=0.7661156420382798, error=0.7661156420382798
# [DEBUG] delta=0.16596210418156132, w_grad=[0.66384842 1.32769683 0.        ], b_grad=0.16596210418156132
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.5058885  -0.05832709  0.38234721], b_before=-0.3704309356349585
# [DEBUG] w_after=[ 0.43950366 -0.19109678  0.38234721], b_after=-0.3870271460531146
# [DEBUG] input=[ 9 13  1], weighted_sum=1.466594924794408, predicted=0.8125392795847828
# [DEBUG] epoch=10, sample=7, actual=1, predicted=0.8125392795847828, error=-0.18746072041521722
# [DEBUG] delta=-0.0399077337703698, w_grad=[-0.3591696  -0.51880054 -0.03990773], b_grad=-0.0399077337703698
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.43950366 -0.19109678  0.38234721], b_before=-0.3870271460531146
# [DEBUG] w_after=[ 0.47542062 -0.13921672  0.38633799], b_after=-0.38303637267607765
# [DEBUG] input=[2 4 0], weighted_sum=0.01093798011118724, predicted=0.5027344677653423
# [DEBUG] epoch=10, sample=8, actual=0, predicted=0.5027344677653423, error=0.5027344677653423
# [DEBUG] delta=0.11806516127834044, w_grad=[0.23613032 0.47226065 0.        ], b_grad=0.11806516127834044
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.47542062 -0.13921672  0.38633799], b_before=-0.38303637267607765
# [DEBUG] w_after=[ 0.45180759 -0.18644279  0.38633799], b_after=-0.3948428888039117
# [DEBUG] input=[6 9 0], weighted_sum=0.6380175637858996, predicted=0.6543051908138905
# [DEBUG] epoch=10, sample=9, actual=0, predicted=0.6543051908138905, error=0.6543051908138905
# [DEBUG] delta=0.1472463639164861, w_grad=[0.88347818 1.32521728 0.        ], b_grad=0.1472463639164861
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.45180759 -0.18644279  0.38633799], b_before=-0.3948428888039117
# [DEBUG] w_after=[ 0.36345977 -0.31896451  0.38633799], b_after=-0.40956752519556033
# [DEBUG] input=[11 16  1], weighted_sum=-1.12860429037641, predicted=0.24441876613668023
# [DEBUG] epoch=10, sample=10, actual=1, predicted=0.24441876613668023, error=-0.7555812338633198
# [DEBUG] delta=-0.1861019857239252, w_grad=[-2.04712184 -2.97763177 -0.18610199], b_grad=-0.1861019857239252
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.36345977 -0.31896451  0.38633799], b_before=-0.40956752519556033
# [DEBUG] w_after=[ 0.56817196 -0.02120134  0.40494819], b_after=-0.3909573266231678
# epoch=10, loss=0.3304906628152556
# [DEBUG] input=[10 15  1], weighted_sum=5.3776903505658415, predicted=0.9954027555832032
# [DEBUG] epoch=11, sample=1, actual=1, predicted=0.9954027555832032, error=-0.004597244416796764
# [DEBUG] delta=-0.0009057916342962789, w_grad=[-0.00905792 -0.01358687 -0.00090579], b_grad=-0.0009057916342962789
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.56817196 -0.02120134  0.40494819], b_before=-0.3909573266231678
# [DEBUG] w_after=[ 0.56907775 -0.01984265  0.40503876], b_after=-0.39086674745973815
# [DEBUG] input=[ 5 10  0], weighted_sum=2.2560954868692065, predicted=0.9051750239708205
# [DEBUG] epoch=11, sample=2, actual=0, predicted=0.9051750239708205, error=0.9051750239708205
# [DEBUG] delta=0.18560703713937474, w_grad=[0.92803519 1.85607037 0.        ], b_grad=0.18560703713937474
# [DEBUG] lr=0.1
# ...
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.98144139 -0.38590844  2.55482949], b_before=-2.3074688035020525
# [DEBUG] w_after=[ 0.98445475 -0.3815558   2.5551643 ], b_after=-2.307133984897792
# [DEBUG] input=[2 4 0], weighted_sum=-1.8644476800255527, predicted=0.1341854804061516
# [DEBUG] epoch=97, sample=8, actual=0, predicted=0.1341854804061516, error=0.1341854804061516
# [DEBUG] delta=0.03339581528240753, w_grad=[0.06679163 0.13358326 0.        ], b_grad=0.03339581528240753
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.98445475 -0.3815558   2.5551643 ], b_before=-2.307133984897792
# [DEBUG] w_after=[ 0.97777559 -0.39491413  2.5551643 ], b_after=-2.3104735664260327
# [DEBUG] input=[6 9 0], weighted_sum=0.0019528369807155777, predicted=0.5004882090900272
# [DEBUG] epoch=97, sample=9, actual=0, predicted=0.5004882090900272, error=0.5004882090900272
# [DEBUG] delta=0.11760251770930868, w_grad=[0.70561511 1.05842266 0.        ], b_grad=0.11760251770930868
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97777559 -0.39491413  2.5551643 ], b_before=-2.3104735664260327
# [DEBUG] w_after=[ 0.90721408 -0.50075639  2.5551643 ], b_after=-2.3222338181969637
# [DEBUG] input=[11 16  1], weighted_sum=2.2001830845056864, predicted=0.9002659507244184
# [DEBUG] epoch=97, sample=10, actual=1, predicted=0.9002659507244184, error=-0.0997340492755816
# [DEBUG] delta=-0.02049307793931528, w_grad=[-0.22542386 -0.32788925 -0.02049308], b_grad=-0.02049307793931528
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.90721408 -0.50075639  2.5551643 ], b_before=-2.3222338181969637
# [DEBUG] w_after=[ 0.92975647 -0.46796747  2.55721361], b_after=-2.320184510403032
# epoch=97, loss=0.06005816417560776
# [DEBUG] input=[10 15  1], weighted_sum=2.515081740551678, predicted=0.9251923660009469
# [DEBUG] epoch=98, sample=1, actual=1, predicted=0.9251923660009469, error=-0.0748076339990531
# [DEBUG] delta=-0.015208486535608443, w_grad=[-0.15208487 -0.2281273  -0.01520849], b_grad=-0.015208486535608443
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.92975647 -0.46796747  2.55721361], b_before=-2.320184510403032
# [DEBUG] w_after=[ 0.94496495 -0.44515474  2.55873446], b_after=-2.318663661749471
# [DEBUG] input=[ 5 10  0], weighted_sum=-2.0453862820851674, predicted=0.11451940257718016
# [DEBUG] epoch=98, sample=2, actual=0, predicted=0.11451940257718016, error=0.11451940257718016
# [DEBUG] delta=0.02853618750908834, w_grad=[0.14268094 0.28536188 0.        ], b_grad=0.02853618750908834
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.94496495 -0.44515474  2.55873446], b_before=-2.318663661749471
# [DEBUG] w_after=[ 0.93069686 -0.47369093  2.55873446], b_after=-2.32151728050038
# [DEBUG] input=[ 8 12  1], weighted_sum=1.9985009412438104, predicted=0.8806395965575783
# [DEBUG] epoch=98, sample=3, actual=1, predicted=0.8806395965575783, error=-0.11936040344242171
# [DEBUG] delta=-0.024727863039482458, w_grad=[-0.1978229  -0.29673436 -0.02472786], b_grad=-0.024727863039482458
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.93069686 -0.47369093  2.55873446], b_before=-2.32151728050038
# [DEBUG] w_after=[ 0.95047915 -0.44401749  2.56120725], b_after=-2.3190444941964317
# [DEBUG] input=[3 5 0], weighted_sum=-1.6876944974150518, predicted=0.15607927681693243
# [DEBUG] epoch=98, sample=4, actual=0, predicted=0.15607927681693243, error=0.15607927681693243
# [DEBUG] delta=0.03878314280033334, w_grad=[0.11634943 0.19391571 0.        ], b_grad=0.03878314280033334
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.95047915 -0.44401749  2.56120725], b_before=-2.3190444941964317
# [DEBUG] w_after=[ 0.93884421 -0.46340906  2.56120725], b_after=-2.322922808476465
# [DEBUG] input=[ 7 14  1], weighted_sum=0.3224670219356782, predicted=0.5799253663595931
# [DEBUG] epoch=98, sample=5, actual=1, predicted=0.5799253663595931, error=-0.42007463364040687
# [DEBUG] delta=-0.09666120291035236, w_grad=[-0.67662842 -1.35325684 -0.0966612 ], b_grad=-0.09666120291035236
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.93884421 -0.46340906  2.56120725], b_before=-2.322922808476465
# [DEBUG] w_after=[ 1.00650705 -0.32808338  2.57087337], b_after=-2.31325668818543
# [DEBUG] input=[4 8 0], weighted_sum=-0.9118955144562957, predicted=0.28661211301819867
# [DEBUG] epoch=98, sample=6, actual=0, predicted=0.28661211301819867, error=0.28661211301819867
# [DEBUG] delta=0.07020143143900583, w_grad=[0.28080573 0.56161145 0.        ], b_grad=0.07020143143900583
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 1.00650705 -0.32808338  2.57087337], b_before=-2.31325668818543
# [DEBUG] w_after=[ 0.97842648 -0.38424452  2.57087337], b_after=-2.3202768313293305
# [DEBUG] input=[ 9 13  1], weighted_sum=4.061256024633974, predicted=0.9830643884811193
# [DEBUG] epoch=98, sample=7, actual=1, predicted=0.9830643884811193, error=-0.016935611518880678
# [DEBUG] delta=-0.003355715189335486, w_grad=[-0.03020144 -0.0436243  -0.00335572], b_grad=-0.003355715189335486
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97842648 -0.38424452  2.57087337], b_before=-2.3202768313293305
# [DEBUG] w_after=[ 0.98144662 -0.37988209  2.57120894], b_after=-2.319941259810397
# [DEBUG] input=[2 4 0], weighted_sum=-1.8765763923765046, predicted=0.1327826113218789
# [DEBUG] epoch=98, sample=8, actual=0, predicted=0.1327826113218789, error=0.1327826113218789
# [DEBUG] delta=0.0330497617456118, w_grad=[0.06609952 0.13219905 0.        ], b_grad=0.0330497617456118
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.98144662 -0.37988209  2.57120894], b_before=-2.319941259810397
# [DEBUG] w_after=[ 0.97483667 -0.393102    2.57120894], b_after=-2.323246235984958
# [DEBUG] input=[6 9 0], weighted_sum=-0.012144211504206748, predicted=0.49696398443696177
# [DEBUG] epoch=98, sample=9, actual=0, predicted=0.49696398443696177, error=0.49696398443696177
# [DEBUG] delta=0.11687500137839088, w_grad=[0.70125001 1.05187501 0.        ], b_grad=0.11687500137839088
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97483667 -0.393102    2.57120894], b_before=-2.323246235984958
# [DEBUG] w_after=[ 0.90471167 -0.4982895   2.57120894], b_after=-2.334933736122797
# [DEBUG] input=[11 16  1], weighted_sum=2.2154715514209213, predicted=0.90163028333889
# [DEBUG] epoch=98, sample=10, actual=1, predicted=0.90163028333889, error=-0.09836971666111005
# [DEBUG] delta=-0.020201096573299132, w_grad=[-0.22221206 -0.32321755 -0.0202011 ], b_grad=-0.020201096573299132
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.90471167 -0.4982895   2.57120894], b_before=-2.334933736122797
# [DEBUG] w_after=[ 0.92693287 -0.46596774  2.57322905], b_after=-2.332913626465467
# epoch=98, loss=0.05904955631801071
# [DEBUG] input=[10 15  1], weighted_sum=2.5201279833463865, predicted=0.9255408752819807
# [DEBUG] epoch=99, sample=1, actual=1, predicted=0.9255408752819807, error=-0.0744591247180193
# [DEBUG] delta=-0.015135353850973293, w_grad=[-0.15135354 -0.22703031 -0.01513535], b_grad=-0.015135353850973293
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.92693287 -0.46596774  2.57322905], b_before=-2.332913626465467
# [DEBUG] w_after=[ 0.94206823 -0.44326471  2.57474258], b_after=-2.33140009108037
# [DEBUG] input=[ 5 10  0], weighted_sum=-2.053706094418992, predicted=0.11367843636416287
# [DEBUG] epoch=99, sample=2, actual=0, predicted=0.11367843636416287, error=0.11367843636416287
# [DEBUG] delta=0.028327991342888968, w_grad=[0.14163996 0.28327991 0.        ], b_grad=0.028327991342888968
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.94206823 -0.44326471  2.57474258], b_before=-2.33140009108037
# [DEBUG] w_after=[ 0.92790423 -0.4715927   2.57474258], b_after=-2.3342328902146585
# [DEBUG] input=[ 8 12  1], weighted_sum=2.0046310814904222, predicted=0.8812824549968823
# [DEBUG] epoch=99, sample=3, actual=1, predicted=0.8812824549968823, error=-0.11871754500311771
# [DEBUG] delta=-0.02458813671208476, w_grad=[-0.19670509 -0.29505764 -0.02458814], b_grad=-0.02458813671208476
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.92790423 -0.4715927   2.57474258], b_before=-2.3342328902146585
# [DEBUG] w_after=[ 0.94757474 -0.44208694  2.5772014 ], b_after=-2.33177407654345
# [DEBUG] input=[3 5 0], weighted_sum=-1.699484560396161, predicted=0.15453259644838943
# [DEBUG] epoch=99, sample=4, actual=0, predicted=0.15453259644838943, error=0.15453259644838943
# [DEBUG] delta=0.038403420964499536, w_grad=[0.11521026 0.1920171  0.        ], b_grad=0.038403420964499536
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.94757474 -0.44208694  2.5772014 ], b_before=-2.33177407654345
# [DEBUG] w_after=[ 0.93605371 -0.46128865  2.5772014 ], b_after=-2.3356144186399
# [DEBUG] input=[ 7 14  1], weighted_sum=0.33592185797262, predicted=0.5831995546127646
# [DEBUG] epoch=99, sample=5, actual=1, predicted=0.5831995546127646, error=-0.4168004453872354
# [DEBUG] delta=-0.09581901573896479, w_grad=[-0.67073311 -1.34146622 -0.09581902], b_grad=-0.09581901573896479
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.93605371 -0.46128865  2.5772014 ], b_before=-2.3356144186399
# [DEBUG] w_after=[ 1.00312702 -0.32714203  2.5867833 ], b_after=-2.326032517066004
# [DEBUG] input=[4 8 0], weighted_sum=-0.9306606519209959, predicted=0.28279070177870924
# [DEBUG] epoch=99, sample=6, actual=0, predicted=0.28279070177870924, error=0.28279070177870924
# [DEBUG] delta=0.06930286952247884, w_grad=[0.27721148 0.55442296 0.        ], b_grad=0.06930286952247884
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 1.00312702 -0.32714203  2.5867833 ], b_before=-2.326032517066004
# [DEBUG] w_after=[ 0.97540588 -0.38258432  2.5867833 ], b_after=-2.3329628040182517
# [DEBUG] input=[ 9 13  1], weighted_sum=4.058877165199677, predicted=0.9830247377887136
# [DEBUG] epoch=99, sample=7, actual=1, predicted=0.9830247377887136, error=-0.016975262211286424
# [DEBUG] delta=-0.003363632535042985, w_grad=[-0.03027269 -0.04372722 -0.00336363], b_grad=-0.003363632535042985
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97540588 -0.38258432  2.5867833 ], b_before=-2.3329628040182517
# [DEBUG] w_after=[ 0.97843315 -0.3782116   2.58711966], b_after=-2.3326264407647472
# [DEBUG] input=[2 4 0], weighted_sum=-1.8886065585368577, predicted=0.13140343039516658
# [DEBUG] epoch=99, sample=8, actual=0, predicted=0.13140343039516658, error=0.13140343039516658
# [DEBUG] delta=0.032709456896480214, w_grad=[0.06541891 0.13083783 0.        ], b_grad=0.032709456896480214
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97843315 -0.3782116   2.58711966], b_before=-2.3326264407647472
# [DEBUG] w_after=[ 0.97189125 -0.39129539  2.58711966], b_after=-2.3358973864543953
# [DEBUG] input=[6 9 0], weighted_sum=-0.02620832520510552, predicted=0.4934482937120838
# [DEBUG] epoch=99, sample=9, actual=0, predicted=0.4934482937120838, error=0.4934482937120838
# [DEBUG] delta=0.11614723489874172, w_grad=[0.69688341 1.04532511 0.        ], b_grad=0.11614723489874172
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97189125 -0.39129539  2.58711966], b_before=-2.3358973864543953
# [DEBUG] w_after=[ 0.90220291 -0.4958279   2.58711966], b_after=-2.3475121099442693
# [DEBUG] input=[11 16  1], weighted_sum=2.2305932585040638, predicted=0.9029633530699115
# [DEBUG] epoch=99, sample=10, actual=1, predicted=0.9029633530699115, error=-0.09703664693008851
# [DEBUG] delta=-0.019916109394097686, w_grad=[-0.2190772  -0.31865775 -0.01991611], b_grad=-0.019916109394097686
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.90220291 -0.4958279   2.58711966], b_before=-2.3475121099442693
# [DEBUG] w_after=[ 0.92411063 -0.46396212  2.58911127], b_after=-2.3455204990048597
# epoch=99, loss=0.058059666975367616
# [DEBUG] input=[10 15  1], weighted_sum=2.5252652919921155, predicted=0.9258941396591069
# [DEBUG] epoch=100, sample=1, actual=1, predicted=0.9258941396591069, error=-0.07410586034089306
# [DEBUG] delta=-0.015061244711487454, w_grad=[-0.15061245 -0.22591867 -0.01506124], b_grad=-0.015061244711487454
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.92411063 -0.46396212  2.58911127], b_before=-2.3455204990048597
# [DEBUG] w_after=[ 0.93917188 -0.44137025  2.5906174 ], b_after=-2.3440143745337108
# [DEBUG] input=[ 5 10  0], weighted_sum=-2.0618575260284397, predicted=0.11285971632145651
# [DEBUG] epoch=100, sample=2, actual=0, predicted=0.11285971632145651, error=0.11285971632145651
# [DEBUG] delta=0.028125273854899196, w_grad=[0.14062637 0.28125274 0.        ], b_grad=0.028125273854899196
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.93917188 -0.44137025  2.5906174 ], b_before=-2.3440143745337108
# [DEBUG] w_after=[ 0.92510924 -0.46949553  2.5906174 ], b_after=-2.3468269019192007
# [DEBUG] input=[ 8 12  1], weighted_sum=2.010718090965857, predicted=0.8819178238161264
# [DEBUG] epoch=100, sample=3, actual=1, predicted=0.8819178238161264, error=-0.11808217618387362
# [DEBUG] delta=-0.02445010550985166, w_grad=[-0.19560084 -0.29340127 -0.02445011], b_grad=-0.02445010550985166
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.92510924 -0.46949553  2.5906174 ], b_before=-2.3468269019192007
# [DEBUG] w_after=[ 0.94466933 -0.4401554   2.59306241], b_after=-2.3443818913682155
# [DEBUG] input=[3 5 0], weighted_sum=-1.7111509214132292, predicted=0.15301449555522043
# [DEBUG] epoch=100, sample=4, actual=0, predicted=0.15301449555522043, error=0.15301449555522043
# [DEBUG] delta=0.03803058256616424, w_grad=[0.11409175 0.19015291 0.        ], b_grad=0.03803058256616424
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.94466933 -0.4401554   2.59306241], b_before=-2.3443818913682155
# [DEBUG] w_after=[ 0.93326015 -0.45917069  2.59306241], b_after=-2.348184949624832
# [DEBUG] input=[ 7 14  1], weighted_sum=0.34930881689273496, predicted=0.5864499587858241
# [DEBUG] epoch=100, sample=5, actual=1, predicted=0.5864499587858241, error=-0.41355004121417593
# [DEBUG] delta=-0.09498394355329344, w_grad=[-0.6648876  -1.32977521 -0.09498394], b_grad=-0.09498394355329344
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.93326015 -0.45917069  2.59306241], b_before=-2.348184949624832
# [DEBUG] w_after=[ 0.99974891 -0.32619317  2.6025608 ], b_after=-2.3386865552695024
# [DEBUG] input=[4 8 0], weighted_sum=-0.9492362840861213, predicted=0.2790384373501873
# [DEBUG] epoch=100, sample=6, actual=0, predicted=0.2790384373501873, error=0.2790384373501873
# [DEBUG] delta=0.0684191251434281, w_grad=[0.2736765 0.547353  0.       ], b_grad=0.0684191251434281
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.99974891 -0.32619317  2.6025608 ], b_before=-2.3386865552695024
# [DEBUG] w_after=[ 0.97238126 -0.38092847  2.6025608 ], b_after=-2.3455284677838453
# [DEBUG] input=[ 9 13  1], weighted_sum=4.056393554615751, predicted=0.9829832437670911
# [DEBUG] epoch=100, sample=7, actual=1, predicted=0.9829832437670911, error=-0.01701675623290888
# [DEBUG] delta=-0.003371918254638938, w_grad=[-0.03034726 -0.04383494 -0.00337192], b_grad=-0.003371918254638938
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97238126 -0.38092847  2.6025608 ], b_before=-2.3455284677838453
# [DEBUG] w_after=[ 0.97541599 -0.37654498  2.602898  ], b_after=-2.3451912759583813
# [DEBUG] input=[2 4 0], weighted_sum=-1.9005392131579306, predicted=0.13004745824915115
# [DEBUG] epoch=100, sample=8, actual=0, predicted=0.13004745824915115, error=0.13004745824915115
# [DEBUG] delta=0.032374788167773616, w_grad=[0.06474958 0.12949915 0.        ], b_grad=0.032374788167773616
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.97541599 -0.37654498  2.602898  ], b_before=-2.3451912759583813
# [DEBUG] w_after=[ 0.96894103 -0.38949489  2.602898  ], b_after=-2.3484287547751586
# [DEBUG] input=[6 9 0], weighted_sum=-0.04023661389559674, predicted=0.48994220344138284
# [DEBUG] epoch=100, sample=9, actual=0, predicted=0.48994220344138284, error=0.48994220344138284
# [DEBUG] delta=0.11541946493512326, w_grad=[0.69251679 1.03877518 0.        ], b_grad=0.11541946493512326
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.96894103 -0.38949489  2.602898  ], b_before=-2.3484287547751586
# [DEBUG] w_after=[ 0.89968935 -0.49337241  2.602898  ], b_after=-2.359970701268671
# [DEBUG] input=[11 16  1], weighted_sum=2.245551568803545, predicted=0.9042661312537755
# [DEBUG] epoch=100, sample=10, actual=1, predicted=0.9042661312537755, error=-0.09573386874622447
# [DEBUG] delta=-0.019637888312432485, w_grad=[-0.21601677 -0.31420621 -0.01963789], b_grad=-0.019637888312432485
# [DEBUG] lr=0.1
# [DEBUG] w_before=[ 0.89968935 -0.49337241  2.602898  ], b_before=-2.359970701268671
# [DEBUG] w_after=[ 0.92129103 -0.46195179  2.60486178], b_after=-2.3580069124374274
# epoch=100, loss=0.05708821641223143

# %%
neuron.test(X, Y)
# Out:
# [DEBUG] input=[10 15  1], weighted_sum=2.530488297743119, predicted=0.926251715703235
# [DEBUG] input=[ 5 10  0], weighted_sum=-2.3710696767793484, predicted=0.08540554837734203
# [DEBUG] input=[ 8 12  1], weighted_sum=2.0737616125098848, predicted=0.8883266678733718
# [DEBUG] input=[3 5 0], weighted_sum=-1.9038927800725776, predicted=0.12966852255012332
# [DEBUG] input=[ 7 14  1], weighted_sum=0.22856700149825748, predicted=0.5568942724172712
# [DEBUG] input=[4 8 0], weighted_sum=-2.368457123910965, predicted=0.08560983980780305
# [DEBUG] input=[ 9 13  1], weighted_sum=2.533100850611503, predicted=0.9264299792011766
# [DEBUG] input=[2 4 0], weighted_sum=-2.3632320181741964, predicted=0.08601975186179958
# [DEBUG] input=[6 9 0], weighted_sum=-0.9878268567377253, predicted=0.2713415277633772
# [DEBUG] input=[11 16  1], weighted_sum=2.9898275358447366, predicted=0.952112447374728
# {'total': 10, 'accurate': 0, 'wrong': 10}
