# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## L2 Ridge
#
# Regularization Techinque to avoid overfitting
#
# ![Ridge Regression](../_/media/3-ml/l2-ridge.png)

# %%
dataset = pd.read_csv('../_/dataset/0-attrition.csv').select_dtypes(include='number')

# %%
print('\n'.join(dataset.columns))
# Out:
# Employee ID
# Age
# Years at Company
# Monthly Income
# Number of Promotions
# Distance from Home
# Number of Dependents
# Company Tenure

# %%
input_cols = list(dataset.columns)
output_col = 'Monthly Income'
input_cols.remove('Employee ID')
input_cols.remove(output_col)

# %%
x, y = np.array(dataset[input_cols]), np.array(dataset[output_col])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
plt.plot(x_train[:10])
# Out:
# [<matplotlib.lines.Line2D at 0x7fc3321ba570>,
#  <matplotlib.lines.Line2D at 0x7fc3321ba5a0>,
#  <matplotlib.lines.Line2D at 0x7fc3321ba690>,
#  <matplotlib.lines.Line2D at 0x7fc3321ba780>,
#  <matplotlib.lines.Line2D at 0x7fc3321ba840>,
#  <matplotlib.lines.Line2D at 0x7fc3321ba930>]

# %%
plt.plot(y_train[:10])

# %% [markdown]
# ## Linear Model

# %%
from sklearn.linear_model import LinearRegression

m = LinearRegression()
m.fit(x_train, y_train)
  
print(m.coef_)
plt.bar(np.linspace(1, len(m.coef_), len(m.coef_)), m.coef_)
# Out:
# [-0.13614417 -0.90304653 11.26173276 -0.17065852  0.51394138 -0.42681067]
# <BarContainer object of 6 artists>

# %%
# skipping largers
c = []
for i in m.coef_:
  if i < 5: c.append(i)
  
print(c)
plt.bar(np.linspace(1, len(c), len(c)), c)
# Out:
# [-0.13614417242051982, -0.9030465281865463, -0.1706585223435367, 0.5139413816026658, -0.426810674369558]
# <BarContainer object of 5 artists>

# %% [markdown]
# ## L2 Model
# Aka Ridge

# %%
from sklearn.linear_model import Ridge

m = Ridge(alpha=5)
m.fit(x_train, y_train)
print(m.coef_)
plt.bar(np.linspace(1, len(m.coef_), len(m.coef_)), m.coef_)
# Out:
# [-0.13614488 -0.90304597 11.26054222 -0.17065889  0.51391711 -0.42681052]
# <BarContainer object of 6 artists>

# %%
# skipping largers
c = []
for i in m.coef_:
  if i < 5: c.append(i)
  
print(c)
plt.bar(np.linspace(1, len(c), len(c)), c)
# Out:
# [-0.13614487888210783, -0.9030459672947866, -0.17065888588025305, 0.5139171051450354, -0.42681052324299223]
# <BarContainer object of 5 artists>
