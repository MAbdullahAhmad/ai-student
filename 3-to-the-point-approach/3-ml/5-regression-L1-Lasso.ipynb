# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## L1 Lasso
#
# Regularization Techinque to de-select negative features

# %%
dataset = pd.read_csv('../_/dataset/0-attrition.csv').select_dtypes(include='number')

# %%
print('\n'.join(dataset.columns))
# Out:
# Employee ID
# Age
# Years at Company
# Monthly Income
# Number of Promotions
# Distance from Home
# Number of Dependents
# Company Tenure

# %%
input_cols = list(dataset.columns)
output_col = 'Monthly Income'
input_cols.remove('Employee ID')
input_cols.remove(output_col)

# %%
x, y = np.array(dataset[input_cols]), np.array(dataset[output_col])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
plt.plot(x_train[:10])
# Out:
# [<matplotlib.lines.Line2D at 0x7fc6ca0971d0>,
#  <matplotlib.lines.Line2D at 0x7fc6ca097200>,
#  <matplotlib.lines.Line2D at 0x7fc6ca0972f0>,
#  <matplotlib.lines.Line2D at 0x7fc6ca0973b0>,
#  <matplotlib.lines.Line2D at 0x7fc6ca0974a0>,
#  <matplotlib.lines.Line2D at 0x7fc6ca097590>]

# %%
plt.plot(y_train[:10])

# %% [markdown]
# ## Linear Model

# %%
from sklearn.linear_model import LinearRegression

m = LinearRegression()
m.fit(x_train, y_train)
  
print(m.coef_)
plt.bar(np.linspace(1, len(m.coef_), len(m.coef_)), m.coef_)
# Out:
# [ 0.42198761 -1.23773237 22.64755494 -0.37400368  2.18529136 -0.49757403]
# <BarContainer object of 6 artists>

# %%
# skipping largers
c = []
for i in m.coef_:
  if i < 5: c.append(i)
  
print(c)
plt.bar(np.linspace(1, len(c), len(c)), c)
# Out:
# [0.42198760737517305, -1.2377323696111222, -0.3740036788974627, 2.185291358651686, -0.4975740284001877]
# <BarContainer object of 5 artists>

# %% [markdown]
# ## L1 Model
# Aka Lasso

# %%
from sklearn.linear_model import Lasso

m = Lasso()
m.fit(x_train, y_train)
print(m.coef_)
plt.bar(np.linspace(1, len(m.coef_), len(m.coef_)), m.coef_)
# Out:
# [ 0.40704705 -1.22099569 21.6362902  -0.37304827  1.76896306 -0.49731244]
# <BarContainer object of 6 artists>

# %%
# skipping largers
c = []
for i in m.coef_:
  if i < 5: c.append(i)
  
print(c)
plt.bar(np.linspace(1, len(c), len(c)), c)
# Out:
# [0.40704704969612887, -1.2209956851697967, -0.37304827142296915, 1.76896306080674, -0.49731243611209935]
# <BarContainer object of 5 artists>
