# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## L1 Lasso
#
# Regularization Techinque to de-select negative features
#
# ![L1 and L2](../_/media/3-ml/l1-lasso-l2-ridge.png)

# %%
dataset = pd.read_csv('../_/dataset/0-attrition.csv').select_dtypes(include='number')

# %%
print('\n'.join(dataset.columns))
# Out:
# Employee ID
# Age
# Years at Company
# Monthly Income
# Number of Promotions
# Distance from Home
# Number of Dependents
# Company Tenure

# %%
input_cols = list(dataset.columns)
output_col = 'Monthly Income'
input_cols.remove('Employee ID')
input_cols.remove(output_col)

# %%
x, y = np.array(dataset[input_cols]), np.array(dataset[output_col])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
plt.plot(x_train[:10])

# %%
plt.plot(y_train[:10])

# %% [markdown]
# ## Linear Model

# %%
from sklearn.linear_model import LinearRegression

m = LinearRegression()
m.fit(x_train, y_train)
  
print(m.coef_)
plt.bar(np.linspace(1, len(m.coef_), len(m.coef_)), m.coef_)
# Out:
# [ 0.45631798 -0.64473621 22.29806125 -0.16646805  6.90675594 -0.4323125 ]
# <BarContainer object of 6 artists>

# %%
# skipping largers
c = []
for i in m.coef_:
  if i < 5: c.append(i)
  
print(c)
plt.bar(np.linspace(1, len(c), len(c)), c)
# Out:
# [0.42198760737517305, -1.2377323696111222, -0.3740036788974627, 2.185291358651686, -0.4975740284001877]
# <BarContainer object of 5 artists>

# %% [markdown]
# ## L1 Model
# Aka Lasso

# %%
from sklearn.linear_model import Lasso

m = Lasso(alpha=20)
m.fit(x_train, y_train)
print(m.coef_)
plt.bar(np.linspace(1, len(m.coef_), len(m.coef_)), m.coef_)
# Out:
# [ 0.15705491 -0.30473116  1.98692092 -0.14924295  0.         -0.43058626]
# <BarContainer object of 6 artists>

# %%
# skipping largers
c = []
for i in m.coef_:
  if i < 5: c.append(i)
  
print(c)
plt.bar(np.linspace(1, len(c), len(c)), c)
# Out:
# [0.15705490892183807, -0.3047311606381831, 1.9869209176841862, -0.14924295200204518, 0.0, -0.4305862619717459]
# <BarContainer object of 6 artists>
